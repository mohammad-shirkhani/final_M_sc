# %%
from google.colab import drive
from pathlib import Path
import json

# Mount Google Drive
drive.mount("/content/drive")

# File path
file_path = Path("/content/drive/MyDrive/final_project/idea_1/hotpotqa_docs_chunks.json")

# 1-based chunk numbers
chunk_numbers = [5449, 6947, 6948, 7536, 25572]

# Load JSON
with open(file_path, "r", encoding="utf-8") as f:
    chunks = json.load(f)

# Show selected chunks
for chunk_number in chunk_numbers:
    idx = chunk_number - 1
    chunk = chunks[idx]

    print("=" * 120)
    print(f"Chunk number: {chunk_number}")
    print(f"Input index : {idx}")
    print(f"Chunk_id    : {chunk['Chunk_id']}")
    print(f"Title       : {chunk['Title']}")
    print(f"Paragraph_id: {chunk['Paragraph_id']}")
    print(f"Token_count : {chunk['Token_count']}")
    print("-" * 120)
    print(chunk["Text"])
    print("\n")
# Out:
# Mounted at /content/drive
# ...
# Chunk number: 5449
# Input index : 5448
# Chunk_id    : hotpotqa_chunk_00005449
# Title       : German language
# Paragraph_id: [34, 35]
# Token_count : 410
# ------------------------------------------------------------------------------------------------------------------------
# ...

# %%
import json

manual_repair_items = json.loads(r'''
[
  {
    "chunk_id": "hotpotqa_chunk_00005449",
    "title": "German language",
    "paragraph_id": [
      34,
      35
    ],
    "token_count": 410,
    "entities": [
      "German language",
      "1843",
      "1910",
      "5 million Germans",
      "United States",
      "United States Brewers' Association",
      "World War I",
      "Pennsylvania",
      "Amish",
      "Hutterites",
      "Mennonites",
      "Hutterite German",
      "Pennsylvania German",
      "Kansas",
      "Volga Germans",
      "North Dakota",
      "Russian Germans",
      "Baltic Germans",
      "Texas",
      "Texas German",
      "Wisconsin",
      "Ohio",
      "German Pietists",
      "Iowa",
      "Amana Colonies",
      "St. Louis",
      "Chicago",
      "New York",
      "Hutterite German",
      "Plautdietsch"
    ],
    "relations": [
      {
        "head": "5 million Germans",
        "relation": "More than 5 million Germans emigrated overseas between 1843 and 1910.",
        "tail": "1843"
      },
      {
        "head": "5 million Germans",
        "relation": "More than 5 million Germans emigrated overseas by 1910.",
        "tail": "1910"
      },
      {
        "head": "5 million Germans",
        "relation": "More than 5 million Germans emigrated mostly to the United States.",
        "tail": "United States"
      },
      {
        "head": "German language",
        "relation": "German remained important in the administration of the United States Brewers' Association.",
        "tail": "United States Brewers' Association"
      },
      {
        "head": "German language",
        "relation": "German was severely repressed during World War I.",
        "tail": "World War I"
      },
      {
        "head": "Pennsylvania",
        "relation": "Small populations of German speakers are still found in Pennsylvania.",
        "tail": "German language"
      },
      {
        "head": "Amish",
        "relation": "Amish historically spoke Pennsylvania German or Pennsylvania Dutch.",
        "tail": "Pennsylvania German"
      },
      {
        "head": "Hutterites",
        "relation": "Hutterites historically spoke Hutterite German.",
        "tail": "Hutterite German"
      },
      {
        "head": "Mennonites",
        "relation": "Mennonites are listed among German-speaking populations in Pennsylvania, Kansas, and North Dakota.",
        "tail": "German language"
      },
      {
        "head": "Kansas",
        "relation": "Mennonites and Volga Germans are listed among German-speaking populations in Kansas.",
        "tail": "Volga Germans"
      },
      {
        "head": "North Dakota",
        "relation": "Russian Germans, Volga Germans, and Baltic Germans are listed among German-speaking populations in North Dakota.",
        "tail": "Russian Germans"
      },
      {
        "head": "North Dakota",
        "relation": "Baltic Germans are listed among German-speaking populations in North Dakota.",
        "tail": "Baltic Germans"
      },
      {
        "head": "Texas German",
        "relation": "Texas German is a German dialect spoken in areas of Texas settled by the Adelsverein.",
        "tail": "Texas"
      },
      {
        "head": "German Pietists",
        "relation": "German Pietists in Iowa formed the Amana Colonies.",
        "tail": "Amana Colonies"
      },
      {
        "head": "Amana Colonies",
        "relation": "The Amana Colonies are located in Iowa.",
        "tail": "Iowa"
      },
      {
        "head": "Amana Colonies",
        "relation": "Amana German is spoken in the Amana Colonies.",
        "tail": "German language"
      },
      {
        "head": "Hutterite German",
        "relation": "Hutterite German resembles dialects of Carinthia.",
        "tail": "German language"
      },
      {
        "head": "Plautdietsch",
        "relation": "Plautdietsch is a large minority language spoken in Northern Mexico by Mennonite communities.",
        "tail": "Mennonites"
      },
      {
        "head": "Pennsylvania German",
        "relation": "Pennsylvania German is spoken by most of the Amish population of Pennsylvania, Ohio, and Indiana.",
        "tail": "Amish"
      },
      {
        "head": "Pennsylvania German",
        "relation": "Pennsylvania German resembles Palatinate German dialects.",
        "tail": "German language"
      }
    ],
    "facts": [
      {
        "entity": "German language",
        "info": "German remained important in churches, schools, newspapers, and the United States Brewers' Association through the early 20th century."
      },
      {
        "entity": "1843",
        "info": "The period of German emigration overseas described in the chunk began in 1843."
      },
      {
        "entity": "1910",
        "info": "The period of German emigration overseas described in the chunk ended in 1910."
      },
      {
        "entity": "5 million Germans",
        "info": "More than 5 million Germans emigrated overseas between 1843 and 1910."
      },
      {
        "entity": "United States",
        "info": "Most German emigrants between 1843 and 1910 went to the United States."
      },
      {
        "entity": "United States Brewers' Association",
        "info": "German remained important in the administration of the United States Brewers' Association through the early 20th century."
      },
      {
        "entity": "World War I",
        "info": "German was severely repressed during World War I."
      },
      {
        "entity": "Pennsylvania",
        "info": "Small populations of German speakers are still found in Pennsylvania."
      },
      {
        "entity": "Amish",
        "info": "Most of the Amish population of Pennsylvania, Ohio, and Indiana speaks Pennsylvania German."
      },
      {
        "entity": "Hutterites",
        "info": "Hutterites historically spoke Hutterite German."
      },
      {
        "entity": "Mennonites",
        "info": "Mennonites are mentioned among German-speaking communities in several regions."
      },
      {
        "entity": "Hutterite German",
        "info": "Hutterite German resembles dialects of Carinthia."
      },
      {
        "entity": "Pennsylvania German",
        "info": "Pennsylvania German is a West Central German dialect."
      },
      {
        "entity": "Kansas",
        "info": "Mennonites and Volga Germans are listed among German-speaking populations in Kansas."
      },
      {
        "entity": "Volga Germans",
        "info": "Volga Germans are listed among German-speaking populations in Kansas and North Dakota."
      },
      {
        "entity": "North Dakota",
        "info": "North Dakota is listed as a place where small populations of German speakers are still found."
      },
      {
        "entity": "Texas German",
        "info": "Texas German is a dialect spoken in areas of Texas settled by the Adelsverein."
      },
      {
        "entity": "German Pietists",
        "info": "German Pietists in Iowa formed the Amana Colonies."
      },
      {
        "entity": "Amana Colonies",
        "info": "The Amana Colonies continue to practice speaking their heritage language."
      },
      {
        "entity": "Plautdietsch",
        "info": "Plautdietsch is spoken by more than 200,000 people in Mexico."
      }
    ],
    "error": null,
    "latency_sec": null,
    "finish_reason": "manual",
    "max_tokens_used": null,
    "usage": null,
    "attempts": [],
    "input_index": 5448,
    "repair_local_index": 0,
    "repair_run": true,
    "manual_extraction": true
  },
  {
    "chunk_id": "hotpotqa_chunk_00006947",
    "title": "1985 Tennessee Volunteers football team",
    "paragraph_id": [
      6,
      7
    ],
    "token_count": 320,
    "entities": [
      "Tony Robinson",
      "1985 season",
      "Heisman Trophy",
      "1984 season",
      "Alan Cockrell",
      "1983",
      "Johnny Majors",
      "1956",
      "Daryl Dickey",
      "Jeff Francis",
      "Randy Sanders",
      "Greg Hargis",
      "Tim McGee",
      "1985 Tennessee Volunteers football team",
      "Eric Swanson",
      "Joey Clinkscales",
      "Vince Carter",
      "Sam Graddy",
      "Jeff Smith",
      "Tim Hendrix"
    ],
    "relations": [
      {
        "head": "Tony Robinson",
        "relation": "Tony Robinson entered the 1985 season as a candidate for the Heisman Trophy.",
        "tail": "Heisman Trophy"
      },
      {
        "head": "Tony Robinson",
        "relation": "Tony Robinson completed 156 of 253 passes for 1,963 yards during the 1984 season.",
        "tail": "1984 season"
      },
      {
        "head": "Tony Robinson",
        "relation": "Tony Robinson fell short of Alan Cockrell's single-season passing record.",
        "tail": "Alan Cockrell"
      },
      {
        "head": "Alan Cockrell",
        "relation": "Alan Cockrell set a single-season passing record of 2,021 yards in 1983.",
        "tail": "1983"
      },
      {
        "head": "Tony Robinson",
        "relation": "Tony Robinson broke the single-season completion percentage record set by Johnny Majors.",
        "tail": "Johnny Majors"
      },
      {
        "head": "Johnny Majors",
        "relation": "Johnny Majors set the earlier single-season completion percentage record in 1956.",
        "tail": "1956"
      },
      {
        "head": "Daryl Dickey",
        "relation": "Daryl Dickey was Tony Robinson's backup.",
        "tail": "Tony Robinson"
      },
      {
        "head": "Daryl Dickey",
        "relation": "Daryl Dickey started the final seven games after Tony Robinson suffered a season-ending knee injury.",
        "tail": "Tony Robinson"
      },
      {
        "head": "Jeff Francis",
        "relation": "Jeff Francis competed for the third-string quarterback slot.",
        "tail": "1985 Tennessee Volunteers football team"
      },
      {
        "head": "Randy Sanders",
        "relation": "Randy Sanders competed for the third-string quarterback slot.",
        "tail": "1985 Tennessee Volunteers football team"
      },
      {
        "head": "Greg Hargis",
        "relation": "Greg Hargis competed for the third-string quarterback slot.",
        "tail": "1985 Tennessee Volunteers football team"
      },
      {
        "head": "Tim McGee",
        "relation": "Tim McGee was the leading returning wide receiver.",
        "tail": "1985 Tennessee Volunteers football team"
      },
      {
        "head": "Tim McGee",
        "relation": "Tim McGee caught a school record 54 passes in 1984.",
        "tail": "1984 season"
      },
      {
        "head": "Tim McGee",
        "relation": "Tim McGee entered the 1985 season needing 45 catches, 828 yards, and 5 touchdowns to set school career records.",
        "tail": "1985 season"
      },
      {
        "head": "Eric Swanson",
        "relation": "Eric Swanson joined Tim McGee in the starting lineup.",
        "tail": "Tim McGee"
      },
      {
        "head": "Joey Clinkscales",
        "relation": "Joey Clinkscales would see significant playing time.",
        "tail": "1985 Tennessee Volunteers football team"
      },
      {
        "head": "Vince Carter",
        "relation": "Vince Carter would see significant playing time.",
        "tail": "1985 Tennessee Volunteers football team"
      },
      {
        "head": "Sam Graddy",
        "relation": "Sam Graddy joined the team as a receiver during spring practice.",
        "tail": "1985 Tennessee Volunteers football team"
      },
      {
        "head": "Jeff Smith",
        "relation": "Jeff Smith was the team's starting tight end.",
        "tail": "1985 Tennessee Volunteers football team"
      },
      {
        "head": "Tim Hendrix",
        "relation": "Tim Hendrix would see significant playing time at tight end.",
        "tail": "1985 Tennessee Volunteers football team"
      }
    ],
    "facts": [
      {
        "entity": "Tony Robinson",
        "info": "Tony Robinson entered the 1985 season as a Heisman Trophy candidate."
      },
      {
        "entity": "1985 season",
        "info": "The chunk describes Tennessee players entering the 1985 season."
      },
      {
        "entity": "Heisman Trophy",
        "info": "Tony Robinson was a candidate for the Heisman Trophy entering the 1985 season."
      },
      {
        "entity": "1984 season",
        "info": "Tony Robinson passed for 1,963 yards during the 1984 season."
      },
      {
        "entity": "Alan Cockrell",
        "info": "Alan Cockrell held a single-season passing record of 2,021 yards."
      },
      {
        "entity": "1983",
        "info": "Alan Cockrell set his single-season passing record in 1983."
      },
      {
        "entity": "Johnny Majors",
        "info": "Johnny Majors had set a single-season completion percentage record broken by Tony Robinson."
      },
      {
        "entity": "1956",
        "info": "Johnny Majors set the earlier completion percentage record in 1956."
      },
      {
        "entity": "Daryl Dickey",
        "info": "Daryl Dickey started the final seven games after Tony Robinson's injury."
      },
      {
        "entity": "Jeff Francis",
        "info": "Jeff Francis competed for the third-string quarterback slot."
      },
      {
        "entity": "Randy Sanders",
        "info": "Randy Sanders competed for the third-string quarterback slot."
      },
      {
        "entity": "Greg Hargis",
        "info": "Greg Hargis competed for the third-string quarterback slot."
      },
      {
        "entity": "Tim McGee",
        "info": "Tim McGee was the leading returning wide receiver."
      },
      {
        "entity": "Eric Swanson",
        "info": "Eric Swanson joined Tim McGee in the starting lineup."
      },
      {
        "entity": "Joey Clinkscales",
        "info": "Joey Clinkscales would see significant playing time."
      },
      {
        "entity": "Vince Carter",
        "info": "Vince Carter would see significant playing time."
      },
      {
        "entity": "Sam Graddy",
        "info": "Sam Graddy joined the team as a receiver during spring practice."
      },
      {
        "entity": "Jeff Smith",
        "info": "Jeff Smith was the team's starting tight end."
      },
      {
        "entity": "Tim Hendrix",
        "info": "Tim Hendrix would see significant playing time."
      },
      {
        "entity": "1985 Tennessee Volunteers football team",
        "info": "The chunk describes offensive players on the 1985 Tennessee Volunteers football team."
      }
    ],
    "error": null,
    "latency_sec": null,
    "finish_reason": "manual",
    "max_tokens_used": null,
    "usage": null,
    "attempts": [],
    "input_index": 6946,
    "repair_local_index": 1,
    "repair_run": true,
    "manual_extraction": true
  },
  {
    "chunk_id": "hotpotqa_chunk_00006948",
    "title": "1985 Tennessee Volunteers football team",
    "paragraph_id": [
      8,
      9,
      10,
      11
    ],
    "token_count": 481,
    "entities": [
      "1985 Tennessee Volunteers football team",
      "Johnnie Jones",
      "Charles Wilson",
      "Keith Davis",
      "Pete Panuska",
      "Jeff Powell",
      "Sam Henderson",
      "William Howard",
      "Jim Miller",
      "Raleigh McKenzie",
      "Bill Mayo",
      "David Douglas",
      "Bruce Wilkerson",
      "Daryle Smith",
      "John Bruhin",
      "Harry Galbreath",
      "Todd Kirk",
      "Tony Williams",
      "Carl Zander",
      "Alvin Toles",
      "Reggie McKenzie",
      "Dale Jones",
      "Lavoisier Fisher",
      "Tyrone Robinson",
      "Tommy Sims",
      "Terry Brown",
      "Charles Davis",
      "Chris White",
      "All-American honors",
      "NFL Draft"
    ],
    "relations": [
      {
        "head": "Johnnie Jones",
        "relation": "Johnnie Jones was a 2nd-team All American whose graduation left the running back slot open.",
        "tail": "1985 Tennessee Volunteers football team"
      },
      {
        "head": "Charles Wilson",
        "relation": "Charles Wilson began the season as the starter at running back.",
        "tail": "1985 Tennessee Volunteers football team"
      },
      {
        "head": "Keith Davis",
        "relation": "Keith Davis joined Charles Wilson at running back.",
        "tail": "Charles Wilson"
      },
      {
        "head": "Pete Panuska",
        "relation": "Pete Panuska joined Charles Wilson at running back.",
        "tail": "Charles Wilson"
      },
      {
        "head": "Jeff Powell",
        "relation": "Jeff Powell was a notable addition to the running back corps.",
        "tail": "1985 Tennessee Volunteers football team"
      },
      {
        "head": "Sam Henderson",
        "relation": "Sam Henderson handled fullback duties.",
        "tail": "1985 Tennessee Volunteers football team"
      },
      {
        "head": "William Howard",
        "relation": "William Howard handled fullback duties.",
        "tail": "1985 Tennessee Volunteers football team"
      },
      {
        "head": "Jim Miller",
        "relation": "Jim Miller handled fullback duties.",
        "tail": "1985 Tennessee Volunteers football team"
      },
      {
        "head": "Raleigh McKenzie",
        "relation": "Raleigh McKenzie was lost from the offensive line to graduation.",
        "tail": "1985 Tennessee Volunteers football team"
      },
      {
        "head": "Bill Mayo",
        "relation": "Bill Mayo was lost from the offensive line to graduation.",
        "tail": "1985 Tennessee Volunteers football team"
      },
      {
        "head": "David Douglas",
        "relation": "David Douglas returned on the offensive line.",
        "tail": "1985 Tennessee Volunteers football team"
      },
      {
        "head": "Bruce Wilkerson",
        "relation": "Bruce Wilkerson returned on the offensive line.",
        "tail": "1985 Tennessee Volunteers football team"
      },
      {
        "head": "Daryle Smith",
        "relation": "Daryle Smith returned on the offensive line.",
        "tail": "1985 Tennessee Volunteers football team"
      },
      {
        "head": "John Bruhin",
        "relation": "John Bruhin returned on the offensive line.",
        "tail": "1985 Tennessee Volunteers football team"
      },
      {
        "head": "Harry Galbreath",
        "relation": "Harry Galbreath returned on the offensive line.",
        "tail": "1985 Tennessee Volunteers football team"
      },
      {
        "head": "Todd Kirk",
        "relation": "Todd Kirk was the starting center.",
        "tail": "1985 Tennessee Volunteers football team"
      },
      {
        "head": "Tony Williams",
        "relation": "Tony Williams would also see playing time.",
        "tail": "1985 Tennessee Volunteers football team"
      },
      {
        "head": "Carl Zander",
        "relation": "Carl Zander was a linebacker lost by the Vols to the NFL Draft.",
        "tail": "NFL Draft"
      },
      {
        "head": "Alvin Toles",
        "relation": "Alvin Toles was a linebacker lost by the Vols to the NFL Draft.",
        "tail": "NFL Draft"
      },
      {
        "head": "Reggie McKenzie",
        "relation": "Reggie McKenzie was a linebacker lost by the Vols to the NFL Draft.",
        "tail": "NFL Draft"
      },
      {
        "head": "Dale Jones",
        "relation": "Dale Jones was the key returning linebacker.",
        "tail": "1985 Tennessee Volunteers football team"
      },
      {
        "head": "Lavoisier Fisher",
        "relation": "Lavoisier Fisher joined Dale Jones among the linebackers.",
        "tail": "Dale Jones"
      },
      {
        "head": "Tyrone Robinson",
        "relation": "Tyrone Robinson joined Dale Jones among the linebackers.",
        "tail": "Dale Jones"
      },
      {
        "head": "Tommy Sims",
        "relation": "Tommy Sims was part of the Vols' secondary.",
        "tail": "1985 Tennessee Volunteers football team"
      },
      {
        "head": "Terry Brown",
        "relation": "Terry Brown was part of the Vols' secondary.",
        "tail": "1985 Tennessee Volunteers football team"
      },
      {
        "head": "Charles Davis",
        "relation": "Charles Davis joined Tommy Sims and Terry Brown in the secondary.",
        "tail": "Tommy Sims"
      },
      {
        "head": "Chris White",
        "relation": "Chris White came off the bench to lead the team with 9 interceptions.",
        "tail": "1985 Tennessee Volunteers football team"
      },
      {
        "head": "Chris White",
        "relation": "Chris White received All-American honors.",
        "tail": "All-American honors"
      }
    ],
    "facts": [
      {
        "entity": "1985 Tennessee Volunteers football team",
        "info": "The chunk describes running backs, fullbacks, linemen, linebackers, defensive linemen, and secondary players."
      },
      {
        "entity": "Johnnie Jones",
        "info": "Johnnie Jones was a 2nd-team All American whose graduation left the running back slot wide open."
      },
      {
        "entity": "Charles Wilson",
        "info": "Charles Wilson began the season as the starting running back."
      },
      {
        "entity": "Keith Davis",
        "info": "Keith Davis was a redshirt freshman running back."
      },
      {
        "entity": "Pete Panuska",
        "info": "Pete Panuska was a junior running back."
      },
      {
        "entity": "Jeff Powell",
        "info": "Jeff Powell was a track team member added to the running back corps."
      },
      {
        "entity": "Sam Henderson",
        "info": "Sam Henderson handled fullback duties."
      },
      {
        "entity": "William Howard",
        "info": "William Howard handled fullback duties."
      },
      {
        "entity": "Jim Miller",
        "info": "Jim Miller handled fullback duties."
      },
      {
        "entity": "Raleigh McKenzie",
        "info": "Raleigh McKenzie was lost from the offensive line to graduation."
      },
      {
        "entity": "Bill Mayo",
        "info": "Bill Mayo was lost from the offensive line to graduation."
      },
      {
        "entity": "David Douglas",
        "info": "David Douglas returned on the offensive line and was a future NFL player."
      },
      {
        "entity": "Bruce Wilkerson",
        "info": "Bruce Wilkerson returned on the offensive line and was a future NFL player."
      },
      {
        "entity": "Daryle Smith",
        "info": "Daryle Smith returned on the offensive line and was a future NFL player."
      },
      {
        "entity": "John Bruhin",
        "info": "John Bruhin returned on the offensive line and was a future NFL player."
      },
      {
        "entity": "Harry Galbreath",
        "info": "Harry Galbreath returned on the offensive line and was a future NFL player."
      },
      {
        "entity": "Todd Kirk",
        "info": "Todd Kirk was the starting center."
      },
      {
        "entity": "Tony Williams",
        "info": "Tony Williams would also see playing time."
      },
      {
        "entity": "Carl Zander",
        "info": "Carl Zander was one of three linebackers lost to the NFL Draft."
      },
      {
        "entity": "Alvin Toles",
        "info": "Alvin Toles was one of three linebackers lost to the NFL Draft."
      },
      {
        "entity": "Reggie McKenzie",
        "info": "Reggie McKenzie was one of three linebackers lost to the NFL Draft."
      },
      {
        "entity": "Dale Jones",
        "info": "Dale Jones was the key returning linebacker and had registered 109 tackles in 1984."
      },
      {
        "entity": "Tommy Sims",
        "info": "Tommy Sims was part of the secondary considered strongest at the beginning of the season."
      },
      {
        "entity": "Terry Brown",
        "info": "Terry Brown was part of the secondary considered strongest at the beginning of the season."
      },
      {
        "entity": "Chris White",
        "info": "Chris White led the team with 9 interceptions and received All-American honors."
      },
      {
        "entity": "All-American honors",
        "info": "Chris White received All-American honors."
      },
      {
        "entity": "NFL Draft",
        "info": "The Vols lost Carl Zander, Alvin Toles, and Reggie McKenzie to the NFL Draft."
      }
    ],
    "error": null,
    "latency_sec": null,
    "finish_reason": "manual",
    "max_tokens_used": null,
    "usage": null,
    "attempts": [],
    "input_index": 6947,
    "repair_local_index": 2,
    "repair_run": true,
    "manual_extraction": true
  },
  {
    "chunk_id": "hotpotqa_chunk_00007536",
    "title": "Sweden",
    "paragraph_id": [
      70,
      71,
      72,
      73
    ],
    "token_count": 490,
    "entities": [
      "Sweden",
      "Swedish Social Democratic Party",
      "1917",
      "Reformists",
      "1932",
      "Social Democrats",
      "World War II",
      "1976",
      "1979",
      "1991",
      "2006",
      "2010",
      "Riksdag",
      "Moderate Party",
      "Centre Party",
      "Liberal People's Party",
      "Left Party",
      "Green Party",
      "1988 election",
      "Christian Democrats",
      "New Democracy",
      "1994 election",
      "Sweden Democrats",
      "European Parliament",
      "June List",
      "Pirate Party",
      "Feminist Initiative",
      "Alliance for Sweden",
      "2014 general election",
      "Stefan Löfven"
    ],
    "relations": [
      {
        "head": "Swedish Social Democratic Party",
        "relation": "The Swedish Social Democratic Party has played a leading role in Swedish politics since 1917.",
        "tail": "1917"
      },
      {
        "head": "Reformists",
        "relation": "The Reformists had confirmed their strength before the Swedish Social Democratic Party played a leading role.",
        "tail": "Swedish Social Democratic Party"
      },
      {
        "head": "Social Democrats",
        "relation": "Most Swedish governments after 1932 have been dominated by the Social Democrats.",
        "tail": "1932"
      },
      {
        "head": "1976",
        "relation": "The 1976 general election gave centre-right parties enough seats in the Riksdag to form a government.",
        "tail": "Riksdag"
      },
      {
        "head": "1979",
        "relation": "The 1979 general election gave centre-right parties enough seats in the Riksdag to form a government.",
        "tail": "Riksdag"
      },
      {
        "head": "1991",
        "relation": "The 1991 general election gave centre-right parties enough seats in the Riksdag to form a government.",
        "tail": "Riksdag"
      },
      {
        "head": "2006",
        "relation": "The 2006 general election gave centre-right parties enough seats in the Riksdag to form a government.",
        "tail": "Riksdag"
      },
      {
        "head": "2010",
        "relation": "The 2010 general election gave centre-right parties enough seats in the Riksdag to form a government.",
        "tail": "Riksdag"
      },
      {
        "head": "Green Party",
        "relation": "The Green Party became the sixth party to gain Riksdag seats in the 1988 election.",
        "tail": "1988 election"
      },
      {
        "head": "Christian Democrats",
        "relation": "The Christian Democrats gained seats for the first time in the 1991 election.",
        "tail": "1991"
      },
      {
        "head": "New Democracy",
        "relation": "New Democracy gained seats for the first time in the 1991 election.",
        "tail": "1991"
      },
      {
        "head": "Green Party",
        "relation": "The Green Party returned in the 1994 election.",
        "tail": "1994 election"
      },
      {
        "head": "New Democracy",
        "relation": "New Democracy declined in the 1994 election.",
        "tail": "1994 election"
      },
      {
        "head": "Sweden Democrats",
        "relation": "The Sweden Democrats gained Riksdag seats in the 2010 elections.",
        "tail": "2010"
      },
      {
        "head": "June List",
        "relation": "The June List gained representation in the European Parliament from 2004 to 2009.",
        "tail": "European Parliament"
      },
      {
        "head": "Pirate Party",
        "relation": "The Pirate Party gained representation in the European Parliament from 2009 to 2014.",
        "tail": "European Parliament"
      },
      {
        "head": "Feminist Initiative",
        "relation": "Feminist Initiative gained representation in the European Parliament from 2014 onward.",
        "tail": "European Parliament"
      },
      {
        "head": "Moderate Party",
        "relation": "The Moderate Party formed the centre-right Alliance for Sweden bloc in the 2006 general election.",
        "tail": "Alliance for Sweden"
      },
      {
        "head": "Alliance for Sweden",
        "relation": "The Alliance for Sweden won a majority of Riksdag seats in the 2006 general election.",
        "tail": "2006"
      },
      {
        "head": "Alliance for Sweden",
        "relation": "The Alliance won a plurality of 173 seats in the 2010 general election.",
        "tail": "2010"
      },
      {
        "head": "Social Democrats",
        "relation": "The Social Democrats were part of the unified left bloc in the 2010 general election.",
        "tail": "2010"
      },
      {
        "head": "Green Party",
        "relation": "The Green Party was part of the unified left bloc in the 2010 general election.",
        "tail": "2010"
      },
      {
        "head": "Left Party",
        "relation": "The Left Party was part of the unified left bloc in the 2010 general election.",
        "tail": "2010"
      },
      {
        "head": "2014 general election",
        "relation": "The 2014 general election gave more seats to the three centre-left parties than to Alliance for Sweden.",
        "tail": "Alliance for Sweden"
      },
      {
        "head": "Sweden Democrats",
        "relation": "The Sweden Democrats won 49 seats in the 2014 general election.",
        "tail": "2014 general election"
      },
      {
        "head": "Stefan Löfven",
        "relation": "Stefan Löfven formed a minority government on 3 October 2014.",
        "tail": "Social Democrats"
      },
      {
        "head": "Stefan Löfven",
        "relation": "Stefan Löfven formed a minority government consisting of the Social Democrats and the Greens.",
        "tail": "Green Party"
      }
    ],
    "facts": [
      {
        "entity": "Sweden",
        "info": "The chunk describes modern Swedish party politics and election outcomes."
      },
      {
        "entity": "Swedish Social Democratic Party",
        "info": "The Swedish Social Democratic Party has played a leading role in Swedish politics since 1917."
      },
      {
        "entity": "1917",
        "info": "The Swedish Social Democratic Party has played a leading role in Swedish politics since 1917."
      },
      {
        "entity": "1932",
        "info": "Most governments after 1932 have been dominated by the Social Democrats."
      },
      {
        "entity": "Social Democrats",
        "info": "The Social Democrats dominated most Swedish governments after 1932."
      },
      {
        "entity": "World War II",
        "info": "Only five general elections since World War II gave centre-right parties enough seats to form a government."
      },
      {
        "entity": "Riksdag",
        "info": "The Riksdag is the parliament in which Swedish parties gained seats."
      },
      {
        "entity": "Moderate Party",
        "info": "The Moderate Party formed the centre-right Alliance for Sweden bloc in the 2006 general election."
      },
      {
        "entity": "Centre Party",
        "info": "The Centre Party was one of the long-standing parties that gained Riksdag seats."
      },
      {
        "entity": "Liberal People's Party",
        "info": "The Liberal People's Party was one of the long-standing parties that gained Riksdag seats."
      },
      {
        "entity": "Left Party",
        "info": "The Left Party was part of the unified left bloc in the 2010 general election."
      },
      {
        "entity": "Green Party",
        "info": "The Green Party became the sixth party to gain Riksdag seats in the 1988 election."
      },
      {
        "entity": "Christian Democrats",
        "info": "The Christian Democrats gained Riksdag seats for the first time in the 1991 election."
      },
      {
        "entity": "New Democracy",
        "info": "New Democracy gained seats in the 1991 election and disappeared after the 1994 election."
      },
      {
        "entity": "Sweden Democrats",
        "info": "The Sweden Democrats gained Riksdag seats in 2010 and won 49 seats in 2014."
      },
      {
        "entity": "European Parliament",
        "info": "Some parties that failed to pass the Riksdag threshold gained representation in the European Parliament."
      },
      {
        "entity": "June List",
        "info": "The June List gained European Parliament representation from 2004 to 2009."
      },
      {
        "entity": "Pirate Party",
        "info": "The Pirate Party gained European Parliament representation from 2009 to 2014."
      },
      {
        "entity": "Feminist Initiative",
        "info": "Feminist Initiative gained European Parliament representation from 2014 onward."
      },
      {
        "entity": "Alliance for Sweden",
        "info": "Alliance for Sweden won a Riksdag majority in 2006 and a plurality of 173 seats in 2010."
      },
      {
        "entity": "2014 general election",
        "info": "The 2014 general election gave the centre-left parties 159 seats and Alliance for Sweden 141 seats."
      },
      {
        "entity": "Stefan Löfven",
        "info": "Stefan Löfven formed a minority government of the Social Democrats and the Greens on 3 October 2014."
      }
    ],
    "error": null,
    "latency_sec": null,
    "finish_reason": "manual",
    "max_tokens_used": null,
    "usage": null,
    "attempts": [],
    "input_index": 7535,
    "repair_local_index": 3,
    "repair_run": true,
    "manual_extraction": true
  },
  {
    "chunk_id": "hotpotqa_chunk_00025572",
    "title": "Conquest of the Western Turks",
    "paragraph_id": [
      20,
      21,
      22
    ],
    "token_count": 501,
    "entities": [
      "Su",
      "Tang forces",
      "Baekje",
      "660",
      "Tang Dynasty",
      "Khaganate",
      "Central Asia",
      "Turkic language",
      "Turkic culture",
      "Indo-European languages",
      "Western Regions",
      "Tang China",
      "sancai",
      "Xinjiang",
      "Dunhuang",
      "Hexi Corridor",
      "Gaozong",
      "Western Turks",
      "662",
      "Beshbalik",
      "Dzungaria",
      "Pamir Mountains",
      "Tajikistan",
      "Afghanistan",
      "Tibetan Empire",
      "Tarim Basin",
      "670",
      "693",
      "Kashgar",
      "Battle of Talas"
    ],
    "relations": [
      {
        "head": "Su",
        "relation": "Su commanded Tang forces in a war against Baekje in 660.",
        "tail": "Baekje"
      },
      {
        "head": "Su",
        "relation": "Su commanded Tang forces.",
        "tail": "Tang forces"
      },
      {
        "head": "Baekje",
        "relation": "Tang forces fought Baekje in 660.",
        "tail": "660"
      },
      {
        "head": "Tang Dynasty",
        "relation": "The Tang Dynasty achieved its maximum extent after the conquest of the Khaganate.",
        "tail": "Khaganate"
      },
      {
        "head": "Tang Dynasty",
        "relation": "Tang military activity in Central Asia brought Turkic migrants into the Tang military.",
        "tail": "Central Asia"
      },
      {
        "head": "Turkic language",
        "relation": "Turkic language spread as Turkic migrants served in the Tang military.",
        "tail": "Tang Dynasty"
      },
      {
        "head": "Turkic culture",
        "relation": "Turkic culture spread as Turkic migrants served in the Tang military.",
        "tail": "Tang Dynasty"
      },
      {
        "head": "Indo-European languages",
        "relation": "Indo-European languages declined in prevalence in the Western Regions.",
        "tail": "Western Regions"
      },
      {
        "head": "Central Asia",
        "relation": "Central Asia absorbed cultural influences from Tang China.",
        "tail": "Tang China"
      },
      {
        "head": "sancai",
        "relation": "Sancai was a Tang stylistic feature used in pottery.",
        "tail": "Tang China"
      },
      {
        "head": "Xinjiang",
        "relation": "Chinese coins remained in circulation in Xinjiang after the decline of the Tang.",
        "tail": "Tang Dynasty"
      },
      {
        "head": "Dunhuang",
        "relation": "Tang architectural influence remains visible in Buddhist architecture of Dunhuang.",
        "tail": "Tang Dynasty"
      },
      {
        "head": "Dunhuang",
        "relation": "Dunhuang is on the border between the Western Regions and the Hexi Corridor.",
        "tail": "Hexi Corridor"
      },
      {
        "head": "Gaozong",
        "relation": "Gaozong appointed two puppet qaghans to rule over the Western Turks.",
        "tail": "Western Turks"
      },
      {
        "head": "Western Turks",
        "relation": "The puppet qaghans appointed over the Western Turks were overthrown in a rebellion beginning in 662.",
        "tail": "662"
      },
      {
        "head": "662",
        "relation": "The rebellion beginning in 662 reduced Tang's western extent to Beshbalik and Dzungaria.",
        "tail": "Beshbalik"
      },
      {
        "head": "662",
        "relation": "The rebellion beginning in 662 reduced Tang's western extent to Dzungaria.",
        "tail": "Dzungaria"
      },
      {
        "head": "Pamir Mountains",
        "relation": "The rebellion ended direct Tang control of Central Asia beyond the Pamir Mountains.",
        "tail": "Central Asia"
      },
      {
        "head": "Pamir Mountains",
        "relation": "The Pamir Mountains are in modern Tajikistan and Afghanistan.",
        "tail": "Tajikistan"
      },
      {
        "head": "Pamir Mountains",
        "relation": "The Pamir Mountains are in modern Tajikistan and Afghanistan.",
        "tail": "Afghanistan"
      },
      {
        "head": "Tibetan Empire",
        "relation": "The Tibetan Empire threatened China's hold on southern Xinjiang.",
        "tail": "Xinjiang"
      },
      {
        "head": "Tibetan Empire",
        "relation": "Tibet invaded the Tarim Basin in 670.",
        "tail": "Tarim Basin"
      },
      {
        "head": "Tarim Basin",
        "relation": "Tibet invaded the Tarim Basin in 670.",
        "tail": "670"
      },
      {
        "head": "Tang forces",
        "relation": "Tang forces regained the Tarim Basin area in 693.",
        "tail": "693"
      },
      {
        "head": "Tang forces",
        "relation": "Tang forces regained Kashgar in 728.",
        "tail": "Kashgar"
      },
      {
        "head": "Tang Dynasty",
        "relation": "Tang expansion brought China into direct contact with the Umayyad Caliphate.",
        "tail": "Central Asia"
      },
      {
        "head": "Battle of Talas",
        "relation": "Chinese and Islamic troops clashed at the Battle of Talas in 751.",
        "tail": "Tang Dynasty"
      },
      {
        "head": "Battle of Talas",
        "relation": "The Chinese lost against the Arabs at the Battle of Talas.",
        "tail": "Central Asia"
      }
    ],
    "facts": [
      {
        "entity": "Su",
        "info": "Su continued his career as a military general and commanded Tang forces against Baekje in 660."
      },
      {
        "entity": "Tang forces",
        "info": "Tang forces fought Baekje and later regained areas in the Tarim Basin and Kashgar."
      },
      {
        "entity": "Baekje",
        "info": "Baekje was attacked by Tang forces commanded by Su in 660."
      },
      {
        "entity": "660",
        "info": "In 660, Su commanded Tang forces in a war against Baekje."
      },
      {
        "entity": "Tang Dynasty",
        "info": "The Tang Dynasty reached its maximum extent after the conquest of the Khaganate."
      },
      {
        "entity": "Khaganate",
        "info": "The conquest of the Khaganate helped the Tang Dynasty reach its maximum extent."
      },
      {
        "entity": "Central Asia",
        "info": "Central Asia absorbed cultural influences from Tang China."
      },
      {
        "entity": "Turkic language",
        "info": "Tang military activity in Central Asia helped spread Turkic language."
      },
      {
        "entity": "Turkic culture",
        "info": "Tang military activity in Central Asia helped spread Turkic culture."
      },
      {
        "entity": "Indo-European languages",
        "info": "The prevalence of Indo-European languages in the Western Regions declined."
      },
      {
        "entity": "Western Regions",
        "info": "The Western Regions saw a decline in Indo-European languages and bordered Dunhuang."
      },
      {
        "entity": "Tang China",
        "info": "Tang China influenced Central Asian art."
      },
      {
        "entity": "sancai",
        "info": "Sancai three-color glaze was a Tang stylistic feature used in pottery."
      },
      {
        "entity": "Xinjiang",
        "info": "Chinese coins remained in circulation in Xinjiang after the decline of Tang."
      },
      {
        "entity": "Dunhuang",
        "info": "Tang architectural influence remains visible in Buddhist architecture of Dunhuang."
      },
      {
        "entity": "Gaozong",
        "info": "Gaozong appointed two puppet qaghans to rule over the Western Turks."
      },
      {
        "entity": "Western Turks",
        "info": "Two puppet qaghans appointed over the Western Turks were later overthrown."
      },
      {
        "entity": "662",
        "info": "A rebellion beginning in 662 reduced Tang's western extent."
      },
      {
        "entity": "Beshbalik",
        "info": "The rebellion reduced Tang's western extent to Beshbalik and Dzungaria."
      },
      {
        "entity": "Dzungaria",
        "info": "The rebellion reduced Tang's western extent to Beshbalik and Dzungaria."
      },
      {
        "entity": "Pamir Mountains",
        "info": "The rebellion ended direct Tang control beyond the Pamir Mountains."
      },
      {
        "entity": "Tibetan Empire",
        "info": "The Tibetan Empire threatened China's hold on southern Xinjiang."
      },
      {
        "entity": "Tarim Basin",
        "info": "Tibet invaded the Tarim Basin in 670."
      },
      {
        "entity": "Kashgar",
        "info": "Tang forces regained Kashgar in 728."
      },
      {
        "entity": "Battle of Talas",
        "info": "Chinese and Islamic troops clashed at the Battle of Talas in 751."
      }
    ],
    "error": null,
    "latency_sec": null,
    "finish_reason": "manual",
    "max_tokens_used": null,
    "usage": null,
    "attempts": [],
    "input_index": 25571,
    "repair_local_index": 4,
    "repair_run": true,
    "manual_extraction": true
  }
]
''')

manual_repair_items
# Out:
# [{'chunk_id': 'hotpotqa_chunk_00005449',
#   'title': 'German language',
#   'paragraph_id': [34, 35],
#   'token_count': 410,
#   'entities': ['German language',
#    '1843',
#    '1910',
#    '5 million Germans',
#    'United States',
#    "United States Brewers' Association",
#    'World War I',
#    'Pennsylvania',
#    'Amish',
#    'Hutterites',
#    'Mennonites',
#    'Hutterite German',
#    'Pennsylvania German',
#    'Kansas',
#    'Volga Germans',
#    'North Dakota',
#    'Russian Germans',
#    'Baltic Germans',
#    'Texas',
#    'Texas German',
#    'Wisconsin',
#    'Ohio',
#    'German Pietists',
#    'Iowa',
#    'Amana Colonies',
#    'St. Louis',
#    'Chicago',
#    'New York',
#    'Hutterite German',
#    'Plautdietsch'],
#   'relations': [{'head': '5 million Germans',
#     'relation': 'More than 5 million Germans emigrated overseas between 1843 and 1910.',
#     'tail': '1843'},
#    {'head': '5 million Germans',
# ...

# %%
from pathlib import Path
from collections import Counter
from datetime import datetime, timezone
import json
import os
import shutil
import copy

# Paths
KG_DIR = Path("/content/drive/MyDrive/final_project/idea_1/kg")

CLEAN_PATH = KG_DIR / "hotpotqa_kg_extractions_all_00000001_to_00035029.clean.json"
AUDIT_PATH = KG_DIR / "hotpotqa_kg_extractions_all_00000001_to_00035029.clean_audit.json"

BACKUP_CLEAN_PATH = KG_DIR / "hotpotqa_kg_extractions_all_00000001_to_00035029.clean.before_manual_replace.json"
BACKUP_AUDIT_PATH = KG_DIR / "hotpotqa_kg_extractions_all_00000001_to_00035029.clean_audit.before_manual_replace.json"

EXPECTED_INDICES = [5448, 6946, 6947, 7535, 25571]

def atomic_json_dump(obj, path):
    # Safe JSON write.
    tmp_path = path.with_name(path.name + ".tmp")
    with open(tmp_path, "w", encoding="utf-8") as f:
        json.dump(obj, f, ensure_ascii=False, indent=2)
        f.flush()
        os.fsync(f.fileno())
    os.replace(tmp_path, path)

def unique_keep_order(items):
    # Remove duplicates.
    seen = set()
    out = []
    for x in items:
        if x not in seen:
            seen.add(x)
            out.append(x)
    return out

def clean_manual_item(item):
    # Normalize manual item.
    item = copy.deepcopy(item)

    item["entities"] = unique_keep_order(item["entities"])
    entity_set = set(item["entities"])

    item["relations"] = [
        r for r in item["relations"]
        if r["head"] in entity_set and r["tail"] in entity_set
    ]

    item["facts"] = [
        f for f in item["facts"]
        if f["entity"] in entity_set
    ]

    item["error"] = None
    item["latency_sec"] = None
    item["finish_reason"] = "manual"
    item["max_tokens_used"] = None
    item["usage"] = None
    item["attempts"] = []
    item["repair_run"] = True
    item["manual_extraction"] = True
    item["final_clean_source_file"] = "manual_repair_items"
    item["final_clean_source_kind"] = "manual_repair"

    item.pop("raw_response", None)

    return item

# Check manual items.
manual_by_index = {
    item["input_index"]: clean_manual_item(item)
    for item in manual_repair_items
}

if sorted(manual_by_index.keys()) != EXPECTED_INDICES:
    raise RuntimeError(
        f"Wrong manual indices. Expected {EXPECTED_INDICES}, got {sorted(manual_by_index.keys())}"
    )

# Backup original files.
if not BACKUP_CLEAN_PATH.exists():
    shutil.copy2(CLEAN_PATH, BACKUP_CLEAN_PATH)

if AUDIT_PATH.exists() and not BACKUP_AUDIT_PATH.exists():
    shutil.copy2(AUDIT_PATH, BACKUP_AUDIT_PATH)

# Load clean file.
with open(CLEAN_PATH, "r", encoding="utf-8") as f:
    clean_items = json.load(f)

if not isinstance(clean_items, list):
    raise RuntimeError("Clean file is not a list.")

if len(clean_items) != 35029:
    raise RuntimeError(f"Expected 35029 items, got {len(clean_items)}.")

# Replace 5 items.
for idx in EXPECTED_INDICES:
    old_item = clean_items[idx]
    new_item = manual_by_index[idx]

    if old_item.get("input_index") != idx:
        raise RuntimeError(f"input_index mismatch at position {idx}")

    if old_item.get("chunk_id") != new_item.get("chunk_id"):
        raise RuntimeError(
            f"chunk_id mismatch at index {idx}: "
            f"{old_item.get('chunk_id')} != {new_item.get('chunk_id')}"
        )

    clean_items[idx] = new_item

# Final check.
bad_items = []

for i, item in enumerate(clean_items):
    if item.get("input_index") != i:
        bad_items.append((i, "input_index"))
        continue

    if item.get("error") is not None:
        bad_items.append((i, "error"))
        continue

    if not isinstance(item.get("entities"), list):
        bad_items.append((i, "entities"))
        continue

    if not isinstance(item.get("relations"), list):
        bad_items.append((i, "relations"))
        continue

    if not isinstance(item.get("facts"), list):
        bad_items.append((i, "facts"))
        continue

if bad_items:
    raise RuntimeError(f"Bad items remain: {bad_items[:20]}")

# Save updated clean file.
atomic_json_dump(clean_items, CLEAN_PATH)

# Update audit file.
if AUDIT_PATH.exists():
    with open(AUDIT_PATH, "r", encoding="utf-8") as f:
        audit = json.load(f)
else:
    audit = {}

source_counts = Counter(
    item.get("final_clean_source_kind", "unknown")
    for item in clean_items
)

audit.update({
    "dataset": "hotpotqa",
    "clean_output_path": str(CLEAN_PATH),
    "total_chunks": len(clean_items),
    "num_clean_items": len(clean_items),
    "num_missing_indices": 0,
    "num_true_error_indices": 0,
    "missing_input_index_ranges_0_based": [],
    "missing_chunk_number_ranges_1_based": [],
    "true_error_input_index_ranges_0_based": [],
    "true_error_chunk_number_ranges_1_based": [],
    "manual_repair_input_indices_0_based": EXPECTED_INDICES,
    "manual_repair_chunk_numbers_1_based": [i + 1 for i in EXPECTED_INDICES],
    "chosen_sources": dict(source_counts),
    "manual_replacement_done": True,
    "manual_replacement_created_at_utc": datetime.now(timezone.utc).isoformat()
})

atomic_json_dump(audit, AUDIT_PATH)

print("Done.")
print("Updated clean file:", CLEAN_PATH)
print("Updated audit file:", AUDIT_PATH)
print("Backup clean file:", BACKUP_CLEAN_PATH)
print("Backup audit file:", BACKUP_AUDIT_PATH)
print("Manual replaced chunk numbers:", [i + 1 for i in EXPECTED_INDICES])
print("Remaining error items:", 0)
print("Source counts:", dict(source_counts))
# Out:
# Done.
# Updated clean file: /content/drive/MyDrive/final_project/idea_1/kg/hotpotqa_kg_extractions_all_00000001_to_00035029.clean.json
# Updated audit file: /content/drive/MyDrive/final_project/idea_1/kg/hotpotqa_kg_extractions_all_00000001_to_00035029.clean_audit.json
# Backup clean file: /content/drive/MyDrive/final_project/idea_1/kg/hotpotqa_kg_extractions_all_00000001_to_00035029.clean.before_manual_replace.json
# Backup audit file: /content/drive/MyDrive/final_project/idea_1/kg/hotpotqa_kg_extractions_all_00000001_to_00035029.clean_audit.before_manual_replace.json
# Manual replaced chunk numbers: [5449, 6947, 6948, 7536, 25572]
# Remaining error items: 0
# Source counts: {'original_batch': 34981, 'repair_v1': 32, 'repair_safe_retry': 11, 'manual_repair': 5}
