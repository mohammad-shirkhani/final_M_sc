# %%
#cell 1
# Check GPU.
# !nvidia-smi
# Out:
# Fri Jun 12 20:02:39 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA RTX PRO 6000 Blac...    Off |   00000000:05:00.0 Off |                    0 |
# | N/A   25C    P0             45W /  600W |       0MiB /  97887MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
#cell 2
# Install dependencies.
# !pip -q install -U uv

# Basic dependencies.
# !uv pip install --system -U openai tqdm requests psutil pandas

# Install recent vLLM nightly for CUDA 13.0 / Blackwell.
# !uv pip install --system -U vllm --torch-backend=cu130 --extra-index-url https://wheels.vllm.ai/nightly/cu130

# Fallback only if the cu130 line fails:
# !uv pip install --system -U vllm --torch-backend=auto --extra-index-url https://wheels.vllm.ai/nightly

# Version check.
import sys
import torch
import vllm

print("Python:", sys.version)
print("Torch:", torch.__version__)
print("Torch CUDA:", torch.version.cuda)
print("CUDA available:", torch.cuda.is_available())
print("GPU:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else None)
print("vLLM:", vllm.__version__)
# Out:
# Using Python 3.12.13 environment at: /usr
# Resolved 24 packages in 115ms
# Prepared 1 package in 0.25ms
# Uninstalled 1 package in 8ms
# Installed 1 package in 12ms
#  - numpy==2.3.5
#  + numpy==2.4.6
# Using Python 3.12.13 environment at: /usr
# Resolved 189 packages in 3.24s
# Prepared 1 package in 0.22ms
# Uninstalled 1 package in 7ms
# Installed 1 package in 11ms
#  - numpy==2.4.6
#  + numpy==2.3.5
# Python: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# Torch: 2.11.0+cu130
# Torch CUDA: 13.0
# CUDA available: True
# GPU: NVIDIA RTX PRO 6000 Blackwell Server Edition
# vLLM: 0.22.1rc1.dev477+g6635279d8

# %%
#cell 3
# Mount Google Drive and prepare paths.
from google.colab import drive
from pathlib import Path
import shutil
import json
import os

drive.mount("/content/drive")

DATASET_NAME = "2wikimultihopqa"

GDRIVE_INPUT_DIR = Path(
    f"/content/drive/MyDrive/final_project/idea_1/answers/{DATASET_NAME}"
)

INPUT_FILES = [
    "2wikimultihopqa_answer_qwen3.5.json",
    "2wikimultihopqa_answer_gpt_oss.json",
    "2wikimultihopqa_answer_gemma4.json",
]

LOCAL_WORK_DIR = Path(f"/content/{DATASET_NAME}_llm_judge")
LOCAL_INPUT_DIR = LOCAL_WORK_DIR / "inputs"
LOCAL_INPUT_DIR.mkdir(parents=True, exist_ok=True)

GDRIVE_OUTPUT_DIR = GDRIVE_INPUT_DIR / "llm_judge_qwen35_27b"
GDRIVE_OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# Copy files to local disk.
for file_name in INPUT_FILES:
    src = GDRIVE_INPUT_DIR / file_name
    dst = LOCAL_INPUT_DIR / file_name

    assert src.exists(), f"Input file not found: {src}"

    shutil.copy2(src, dst)
    print("Copied:", src, "->", dst)

print("Local input dir:", LOCAL_INPUT_DIR)
print("Output dir:", GDRIVE_OUTPUT_DIR)
# Out:
# Mounted at /content/drive
# Copied: /content/drive/MyDrive/final_project/idea_1/answers/2wikimultihopqa/2wikimultihopqa_answer_qwen3.5.json -> /content/2wikimultihopqa_llm_judge/inputs/2wikimultihopqa_answer_qwen3.5.json
# Copied: /content/drive/MyDrive/final_project/idea_1/answers/2wikimultihopqa/2wikimultihopqa_answer_gpt_oss.json -> /content/2wikimultihopqa_llm_judge/inputs/2wikimultihopqa_answer_gpt_oss.json
# Copied: /content/drive/MyDrive/final_project/idea_1/answers/2wikimultihopqa/2wikimultihopqa_answer_gemma4.json -> /content/2wikimultihopqa_llm_judge/inputs/2wikimultihopqa_answer_gemma4.json
# Local input dir: /content/2wikimultihopqa_llm_judge/inputs
# Output dir: /content/drive/MyDrive/final_project/idea_1/answers/2wikimultihopqa/llm_judge_qwen35_27b

# %%
#cell 4
# Load input JSON files.
from collections import Counter

def load_json_list(path: Path):
    # Load a JSON list.
    with open(path, "r", encoding="utf-8") as f:
        data = json.load(f)

    assert isinstance(data, list), f"Expected a list in {path}"
    return data

all_input_data = {}

for file_name in INPUT_FILES:
    path = LOCAL_INPUT_DIR / file_name
    data = load_json_list(path)
    all_input_data[file_name] = data

    print("\nFile:", file_name)
    print("Rows:", len(data))
    print("Types:", Counter(x.get("type") for x in data))

    if len(data) > 0:
        print("Keys:", sorted(data[0].keys()))
# Out:
# File: 2wikimultihopqa_answer_qwen3.5.json
# Rows: 1000
# Types: Counter({'comparison': 250, 'inference': 250, 'compositional': 250, 'bridge_comparison': 250})
# Keys: ['attempt', 'completion_tokens', 'gt', 'max_tokens_used', 'question', 'response', 'retry_reason', 'source_index', 'type']
#
# File: 2wikimultihopqa_answer_gpt_oss.json
# Rows: 1000
# Types: Counter({'comparison': 250, 'inference': 250, 'compositional': 250, 'bridge_comparison': 250})
# Keys: ['attempt', 'completion_tokens', 'gt', 'max_tokens_used', 'question', 'reasoning_tokens', 'response', 'retry_reason', 'source_index', 'type']
#
# File: 2wikimultihopqa_answer_gemma4.json
# Rows: 1000
# Types: Counter({'comparison': 250, 'inference': 250, 'compositional': 250, 'bridge_comparison': 250})
# Keys: ['attempt', 'completion_tokens', 'gt', 'max_tokens_used', 'question', 'response', 'retry_reason', 'source_index', 'type']

# %%
#cell 5
# Start vLLM server in Qwen non-thinking mode.
import subprocess
import time
import requests
import shlex
import psutil
from pathlib import Path
import os

MODEL_NAME = "Qwen/Qwen3.5-27B"
PORT = 8000
BASE_URL = f"http://localhost:{PORT}/v1"

# Total context length.
MAX_MODEL_LEN = 12288

# Memory margin for RTX PRO 6000 Blackwell 96GB.
GPU_MEMORY_UTILIZATION = 0.92

# Throughput settings.
MAX_NUM_SEQS = 8
MAX_NUM_BATCHED_TOKENS = 16384

SERVER_LOG_PATH = Path("/content/vllm_server.log")
SERVER_PID_PATH = Path("/content/vllm_server.pid")

def kill_process_tree(pid):
    # Kill a process and its children.
    try:
        parent = psutil.Process(int(pid))

        for child in parent.children(recursive=True):
            try:
                child.kill()
            except Exception:
                pass

        parent.kill()
        parent.wait(timeout=10)
        print("Killed old process tree:", pid)

    except Exception:
        pass

# Stop old PID.
if SERVER_PID_PATH.exists():
    old_pid = SERVER_PID_PATH.read_text().strip()
    if old_pid:
        kill_process_tree(old_pid)

# Kill leftover vLLM servers.
for p in psutil.process_iter(["pid", "name", "cmdline"]):
    try:
        cmdline = " ".join(p.info.get("cmdline") or [])
        if "vllm" in cmdline and "serve" in cmdline:
            kill_process_tree(p.info["pid"])
            print("Killed leftover vLLM process:", p.info["pid"])
    except Exception:
        pass

time.sleep(3)

cmd = [
    "vllm", "serve", MODEL_NAME,

    "--host", "0.0.0.0",
    "--port", str(PORT),

    "--max-model-len", str(MAX_MODEL_LEN),
    "--gpu-memory-utilization", str(GPU_MEMORY_UTILIZATION),

    # Text-only mode.
    "--language-model-only",

    # Qwen non-thinking mode.
    "--reasoning-parser", "qwen3",
    "--default-chat-template-kwargs", '{"enable_thinking": false}',

    # Throughput settings.
    "--max-num-seqs", str(MAX_NUM_SEQS),
    "--max-num-batched-tokens", str(MAX_NUM_BATCHED_TOKENS),

    # Shared prompt prefix cache.
    "--enable-prefix-caching",

    # Use vLLM generation config.
    "--generation-config", "vllm",

    # Good dtype for Blackwell.
    "--dtype", "bfloat16",

    # Safe for custom model code.
    "--trust-remote-code",
]

server_env = os.environ.copy()

# Avoid FlashInfer sampler crash in this environment.
server_env["VLLM_USE_FLASHINFER_SAMPLER"] = "0"

# CUDA 13.0 / Blackwell hints.
server_env["VLLM_MAIN_CUDA_VERSION"] = "13.0"
server_env["TORCH_CUDA_ARCH_LIST"] = "12.0"

print("Command:")
print(" ".join(shlex.quote(x) for x in cmd))

print("\nImportant environment variables:")
for k in ["VLLM_USE_FLASHINFER_SAMPLER", "VLLM_MAIN_CUDA_VERSION", "TORCH_CUDA_ARCH_LIST"]:
    print(f"{k}={server_env.get(k)}")

SERVER_LOG_PATH.write_text("", encoding="utf-8")
log_file = open(SERVER_LOG_PATH, "w", encoding="utf-8")

proc = subprocess.Popen(
    cmd,
    stdout=log_file,
    stderr=subprocess.STDOUT,
    text=True,
    env=server_env,
)

SERVER_PID_PATH.write_text(str(proc.pid))

print("\nStarted vLLM server.")
print("PID:", proc.pid)
print("Log:", SERVER_LOG_PATH)
# Out:
# Command:
# vllm serve Qwen/Qwen3.5-27B --host 0.0.0.0 --port 8000 --max-model-len 12288 --gpu-memory-utilization 0.92 --language-model-only --reasoning-parser qwen3 --default-chat-template-kwargs '{"enable_thinking": false}' --max-num-seqs 8 --max-num-batched-tokens 16384 --enable-prefix-caching --generation-config vllm --dtype bfloat16 --trust-remote-code
#
# Important environment variables:
# VLLM_USE_FLASHINFER_SAMPLER=0
# VLLM_MAIN_CUDA_VERSION=13.0
# TORCH_CUDA_ARCH_LIST=12.0
#
# Started vLLM server.
# PID: 2673
# Log: /content/vllm_server.log

# %%
#cell 6
# Wait for vLLM server.
import time
import requests
from pathlib import Path

def tail_log(path, n=80):
    # Return recent log lines.
    path = Path(path)

    if not path.exists():
        return ""

    lines = path.read_text(errors="ignore").splitlines()
    return "\n".join(lines[-n:])

ready = False

MAX_WAIT_SEC = 1800
SLEEP_SEC = 5
PRINT_EVERY_SEC = 60

start = time.perf_counter()
last_print = -PRINT_EVERY_SEC

for step in range(MAX_WAIT_SEC // SLEEP_SEC):
    elapsed = int(time.perf_counter() - start)

    return_code = proc.poll()

    if return_code is not None:
        print(f"vLLM process exited. Return code: {return_code}")
        print("\n=== Last vLLM log lines ===")
        print(tail_log(SERVER_LOG_PATH, n=160))
        raise RuntimeError("vLLM server crashed or exited during startup.")

    try:
        health = requests.get(f"http://localhost:{PORT}/health", timeout=5)

        if health.status_code == 200:
            models = requests.get(f"{BASE_URL}/models", timeout=10)

            if models.status_code == 200:
                ready = True
                model_info = models.json()["data"][0]

                print("vLLM server is ready.")
                print("Model:", model_info["id"])
                print("Max model len:", model_info.get("max_model_len"))
                break

    except Exception:
        pass

    if elapsed - last_print >= PRINT_EVERY_SEC:
        last_print = elapsed
        print(f"Waiting... {elapsed}s")

        recent = tail_log(SERVER_LOG_PATH, n=12)
        if recent.strip():
            print(recent)

        print("-" * 80)

    time.sleep(SLEEP_SEC)

if not ready:
    print("\n=== Last vLLM log lines ===")
    print(tail_log(SERVER_LOG_PATH, n=160))
    raise RuntimeError("vLLM server did not become ready before timeout.")
# Out:
# Waiting... 0s
# --------------------------------------------------------------------------------
# Waiting... 60s
# (EngineCore pid=3207) INFO 06-12 20:06:02 [registry.py:134] All limits of multimodal modalities supported by the model are set to 0, running in text-only mode.
# (EngineCore pid=3207) INFO 06-12 20:06:02 [parallel_state.py:1568] world_size=1 rank=0 local_rank=0 distributed_init_method=tcp://172.28.0.12:51001 backend=nccl
# (EngineCore pid=3207) INFO 06-12 20:06:02 [parallel_state.py:1903] rank 0 in world size 1 is assigned as DP rank 0, PP rank 0, PCP rank 0, TP rank 0, EP rank N/A, EPLB rank N/A
# (EngineCore pid=3207) INFO 06-12 20:06:03 [topk_topp_sampler.py:39] FlashInfer top-p/top-k sampling disabled via VLLM_USE_FLASHINFER_SAMPLER=0.
# (EngineCore pid=3207) INFO 06-12 20:06:03 [gpu_model_runner.py:5087] Starting to load model Qwen/Qwen3.5-27B...
# (EngineCore pid=3207) INFO 06-12 20:06:03 [cuda.py:433] Using backend AttentionBackendEnum.FLASH_ATTN for vit attention
# (EngineCore pid=3207) INFO 06-12 20:06:03 [mm_encoder_attention.py:372] Using AttentionBackendEnum.FLASH_ATTN for MMEncoderAttention.
# (EngineCore pid=3207) INFO 06-12 20:06:03 [qwen_gdn_linear_attn.py:228] Using Triton/FLA GDN prefill kernel (requested=auto, head_k_dim=128).
# (EngineCore pid=3207) Failed to get device capability: SM 12.x requires CUDA >= 12.9.
# (EngineCore pid=3207) Failed to get device capability: SM 12.x requires CUDA >= 12.9.
# (EngineCore pid=3207) INFO 06-12 20:06:04 [cuda.py:378] Using FLASH_ATTN attention backend out of potential backends: ['FLASH_ATTN', 'FLASHINFER', 'TRITON_ATTN', 'FLEX_ATTENTION'].
# (EngineCore pid=3207) INFO 06-12 20:06:04 [flash_attn.py:670] Using FlashAttention version 2
# --------------------------------------------------------------------------------
# Waiting... 120s
# (EngineCore pid=3207) INFO 06-12 20:06:02 [registry.py:134] All limits of multimodal modalities supported by the model are set to 0, running in text-only mode.
# (EngineCore pid=3207) INFO 06-12 20:06:02 [parallel_state.py:1568] world_size=1 rank=0 local_rank=0 distributed_init_method=tcp://172.28.0.12:51001 backend=nccl
# (EngineCore pid=3207) INFO 06-12 20:06:02 [parallel_state.py:1903] rank 0 in world size 1 is assigned as DP rank 0, PP rank 0, PCP rank 0, TP rank 0, EP rank N/A, EPLB rank N/A
# (EngineCore pid=3207) INFO 06-12 20:06:03 [topk_topp_sampler.py:39] FlashInfer top-p/top-k sampling disabled via VLLM_USE_FLASHINFER_SAMPLER=0.
# (EngineCore pid=3207) INFO 06-12 20:06:03 [gpu_model_runner.py:5087] Starting to load model Qwen/Qwen3.5-27B...
# (EngineCore pid=3207) INFO 06-12 20:06:03 [cuda.py:433] Using backend AttentionBackendEnum.FLASH_ATTN for vit attention
# (EngineCore pid=3207) INFO 06-12 20:06:03 [mm_encoder_attention.py:372] Using AttentionBackendEnum.FLASH_ATTN for MMEncoderAttention.
# (EngineCore pid=3207) INFO 06-12 20:06:03 [qwen_gdn_linear_attn.py:228] Using Triton/FLA GDN prefill kernel (requested=auto, head_k_dim=128).
# (EngineCore pid=3207) Failed to get device capability: SM 12.x requires CUDA >= 12.9.
# (EngineCore pid=3207) Failed to get device capability: SM 12.x requires CUDA >= 12.9.
# (EngineCore pid=3207) INFO 06-12 20:06:04 [cuda.py:378] Using FLASH_ATTN attention backend out of potential backends: ['FLASH_ATTN', 'FLASHINFER', 'TRITON_ATTN', 'FLEX_ATTENTION'].
# (EngineCore pid=3207) INFO 06-12 20:06:04 [flash_attn.py:670] Using FlashAttention version 2
# --------------------------------------------------------------------------------
# Waiting... 180s
# (EngineCore pid=3207) INFO 06-12 20:06:02 [registry.py:134] All limits of multimodal modalities supported by the model are set to 0, running in text-only mode.
# (EngineCore pid=3207) INFO 06-12 20:06:02 [parallel_state.py:1568] world_size=1 rank=0 local_rank=0 distributed_init_method=tcp://172.28.0.12:51001 backend=nccl
# (EngineCore pid=3207) INFO 06-12 20:06:02 [parallel_state.py:1903] rank 0 in world size 1 is assigned as DP rank 0, PP rank 0, PCP rank 0, TP rank 0, EP rank N/A, EPLB rank N/A
# (EngineCore pid=3207) INFO 06-12 20:06:03 [topk_topp_sampler.py:39] FlashInfer top-p/top-k sampling disabled via VLLM_USE_FLASHINFER_SAMPLER=0.
# (EngineCore pid=3207) INFO 06-12 20:06:03 [gpu_model_runner.py:5087] Starting to load model Qwen/Qwen3.5-27B...
# (EngineCore pid=3207) INFO 06-12 20:06:03 [cuda.py:433] Using backend AttentionBackendEnum.FLASH_ATTN for vit attention
# (EngineCore pid=3207) INFO 06-12 20:06:03 [mm_encoder_attention.py:372] Using AttentionBackendEnum.FLASH_ATTN for MMEncoderAttention.
# (EngineCore pid=3207) INFO 06-12 20:06:03 [qwen_gdn_linear_attn.py:228] Using Triton/FLA GDN prefill kernel (requested=auto, head_k_dim=128).
# (EngineCore pid=3207) Failed to get device capability: SM 12.x requires CUDA >= 12.9.
# (EngineCore pid=3207) Failed to get device capability: SM 12.x requires CUDA >= 12.9.
# (EngineCore pid=3207) INFO 06-12 20:06:04 [cuda.py:378] Using FLASH_ATTN attention backend out of potential backends: ['FLASH_ATTN', 'FLASHINFER', 'TRITON_ATTN', 'FLEX_ATTENTION'].
# (EngineCore pid=3207) INFO 06-12 20:06:04 [flash_attn.py:670] Using FlashAttention version 2
# --------------------------------------------------------------------------------
# Waiting... 240s
# Loading safetensors checkpoint shards: 100% Completed | 11/11 [00:04<00:00,  2.40it/s]
# (EngineCore pid=3207)
# (EngineCore pid=3207) INFO 06-12 20:08:45 [default_loader.py:397] Loading weights took 4.61 seconds
# (EngineCore pid=3207) INFO 06-12 20:08:45 [gpu_model_runner.py:5182] Model loading took 50.22 GiB memory and 161.608342 seconds
# (EngineCore pid=3207) INFO 06-12 20:08:45 [interface.py:670] Setting attention block size to 784 tokens to ensure that attention page size is >= mamba page size.
# (EngineCore pid=3207) INFO 06-12 20:08:45 [interface.py:694] Padding mamba page size by 0.13% to ensure that mamba page size and attention page size are exactly equal.
# (EngineCore pid=3207) INFO 06-12 20:08:52 [backends.py:1089] Using cache directory: /root/.cache/vllm/torch_compile_cache/b7b57b4a35/rank_0_0/backbone for vLLM's torch.compile
# (EngineCore pid=3207) INFO 06-12 20:08:52 [backends.py:1148] Dynamo bytecode transform time: 6.64 s
# (EngineCore pid=3207) INFO 06-12 20:08:54 [backends.py:378] Cache the graph of compile range (1, 16384) for later use
# (EngineCore pid=3207) INFO 06-12 20:09:07 [backends.py:393] Compiling a graph for compile range (1, 16384) takes 14.59 s
# (EngineCore pid=3207) INFO 06-12 20:09:10 [decorators.py:708] saved AOT compiled function to /root/.cache/vllm/torch_compile_cache/torch_aot_compile/1f9cb63b64acff7f927d62130d0334babc8bde8e08812e7454fa962eed619d2a/rank_0_0/model
# (EngineCore pid=3207) INFO 06-12 20:09:10 [monitor.py:53] torch.compile took 24.05 s in total
# --------------------------------------------------------------------------------
# Waiting... 300s
# (EngineCore pid=3207) WARNING 06-12 20:10:37 [import_utils.py:408]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (EngineCore pid=3207) WARNING 06-12 20:10:37 [import_utils.py:408]   File "<frozen importlib._bootstrap>", line 1387, in _gcd_import
# (EngineCore pid=3207) WARNING 06-12 20:10:37 [import_utils.py:408]   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
# (EngineCore pid=3207) WARNING 06-12 20:10:37 [import_utils.py:408]   File "<frozen importlib._bootstrap>", line 1331, in _find_and_load_unlocked
# (EngineCore pid=3207) WARNING 06-12 20:10:37 [import_utils.py:408]   File "<frozen importlib._bootstrap>", line 935, in _load_unlocked
# (EngineCore pid=3207) WARNING 06-12 20:10:37 [import_utils.py:408]   File "<frozen importlib._bootstrap_external>", line 999, in exec_module
# (EngineCore pid=3207) WARNING 06-12 20:10:37 [import_utils.py:408]   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
# (EngineCore pid=3207) WARNING 06-12 20:10:37 [import_utils.py:408]   File "/usr/local/lib/python3.12/dist-packages/vllm/third_party/deep_gemm/__init__.py", line 16, in <module>
# (EngineCore pid=3207) WARNING 06-12 20:10:37 [import_utils.py:408]     from . import _C
# (EngineCore pid=3207) WARNING 06-12 20:10:37 [import_utils.py:408] ImportError: libnvrtc.so.13: cannot open shared object file: No such file or directory
# (EngineCore pid=3207) 2026-06-12 20:10:37,040 - INFO - autotuner.py:622 - flashinfer.jit: [Autotuner]: Autotuning process starts ...
# (EngineCore pid=3207) 2026-06-12 20:10:37,050 - INFO - autotuner.py:641 - flashinfer.jit: [Autotuner]: Autotuning process ends
# --------------------------------------------------------------------------------
# vLLM server is ready.
# Model: Qwen/Qwen3.5-27B
# Max model len: 12288

# %%
#cell 7
# Define the judge prompt and JSON schema.
JUDGE_SYSTEM_PROMPT = """
You are a strict but fair answer judge.

You will receive:
- a question
- the ground-truth answer
- a candidate LLM response

Your job is to judge whether the candidate response correctly answers the question.
Use the ground-truth answer as the authoritative answer.
Do not solve the question yourself.
Do not add background knowledge.
Do not write analysis outside JSON.

Return only this JSON object, with reason first and score second:
{
  "reason": "short reason",
  "score": 0 or 1
}

Rules:
- Score 1 if the candidate gives the correct answer to the question.
- Score 1 if the candidate is semantically the same as the ground truth, even with different wording.
- Score 1 if the candidate gives the main requested answer clearly and any missing part is only a harmless clarifying suffix.
- Score 1 if the candidate includes extra information that does not contradict the correct answer.
- Score 0 if the candidate is wrong.
- Score 0 if the candidate is incomplete for what the question asks.
- Score 0 if the candidate is vague, too broad, or too narrow.
- Score 0 if the candidate says the answer is unknown, unavailable, cannot be determined, or similar.
- Score 0 if the candidate contains a contradiction or an incorrect final answer.
- Use the question to decide what details are required.
- Do not require exact string matching.
- When unsure, score 0.

Keep the reason short: maximum 25 words.
Do not use double quotation marks inside the reason string.
""".strip()

JUDGE_JSON_SCHEMA = {
    "type": "object",
    "properties": {
        "reason": {
            "type": "string"
        },
        "score": {
            "type": "integer",
            "enum": [0, 1]
        },
    },
    "required": ["reason", "score"],
    "additionalProperties": False,
}

def build_judge_user_prompt(question: str, gt: str, response: str) -> str:
    # Build one judging prompt.
    return f"""
Question:
{question}

Ground-truth answer:
{gt}

Candidate LLM response:
{response}

Judge the candidate response.
Return only JSON with reason first and score second.
""".strip()

# %%
#cell 8
# Create OpenAI-compatible client and JSON parser.
from openai import OpenAI
from typing import Any, Dict
import json
import time
import re

client = OpenAI(
    base_url=BASE_URL,
    api_key="EMPTY",
)

def coerce_malformed_judge_json(text: str) -> Dict[str, Any] | None:
    # Recover judge outputs that look like JSON but contain unescaped quotes inside reason.
    text = (text or "").strip()

    score_match = re.search(r'"score"\s*:\s*"?([01])"?', text)

    if score_match is None:
        score_match = re.search(r"(?im)^\s*score\s*[:=]\s*([01])\s*$", text)

    if score_match is None:
        return None

    score = int(score_match.group(1))

    reason = None
    reason_marker = re.search(r'"reason"\s*:\s*"', text, flags=re.S)

    if reason_marker is not None:
        start = reason_marker.end()
        after = text[start:]

        # Prefer the quote immediately before the next score field.
        sep = re.search(r'"\s*,\s*"score"\s*:', after, flags=re.S)

        if sep is not None:
            reason = after[:sep.start()]
        else:
            # If reason is the final field, use the last quote before the closing brace.
            end = re.search(r'"\s*}\s*$', after, flags=re.S)
            reason = after[:end.start()] if end is not None else after

    if reason is None:
        reason = "Recovered malformed judge JSON."

    reason = reason.replace('\\"', '"')
    reason = reason.replace("\\n", " ")
    reason = reason.replace('"', "'")
    reason = " ".join(reason.split()).strip()

    if not reason:
        reason = "Recovered malformed judge JSON."

    return {
        "reason": reason,
        "score": score,
    }

def extract_first_json_object(text: str) -> Dict[str, Any]:
    # Extract the first JSON object.
    text = (text or "").strip()

    try:
        return json.loads(text)
    except Exception:
        pass

    # Robust fallback for malformed JSON with unescaped quotes in reason.
    recovered = coerce_malformed_judge_json(text)
    if recovered is not None:
        return recovered

    start = text.find("{")

    if start == -1:
        raise ValueError(f"No JSON object found: {text[:300]}")

    depth = 0
    in_str = False
    escape = False

    for i in range(start, len(text)):
        ch = text[i]

        if in_str:
            if escape:
                escape = False
            elif ch == "\\":
                escape = True
            elif ch == '"':
                in_str = False
        else:
            if ch == '"':
                in_str = True
            elif ch == "{":
                depth += 1
            elif ch == "}":
                depth -= 1

                if depth == 0:
                    candidate = text[start:i + 1]

                    try:
                        return json.loads(candidate)
                    except Exception:
                        recovered = coerce_malformed_judge_json(candidate)

                        if recovered is not None:
                            return recovered

                        raise

    recovered = coerce_malformed_judge_json(text)

    if recovered is not None:
        return recovered

    raise ValueError(f"Incomplete JSON object: {text[:300]}")

def normalize_judge_output(obj: Dict[str, Any]) -> Dict[str, Any]:
    # Normalize judge output.
    score = obj.get("score")

    if isinstance(score, str):
        score = score.strip()
        if score in {"0", "1"}:
            score = int(score)

    if score not in {0, 1}:
        raise ValueError(f"Invalid score: {obj}")

    reason = str(obj.get("reason", "")).strip()

    if not reason:
        reason = "No reason provided."

    # Keep reason compact and avoid unsafe inner double quotes.
    reason = reason.replace('"', "'")
    reason = " ".join(reason.split())

    return {
        "reason": reason,
        "score": int(score),
    }

# %%
#cell 9
# Define one judge call with guided JSON and retries.
JUDGE_TEMPERATURE = 0.0
JUDGE_MAX_TOKENS = 512
MAX_RETRIES = 5

def judge_one_record(record: Dict[str, Any]) -> Dict[str, Any]:
    # Judge one row.
    question = str(record.get("question", ""))
    gt = str(record.get("gt", ""))
    response = str(record.get("response", ""))

    messages = [
        {
            "role": "system",
            "content": JUDGE_SYSTEM_PROMPT,
        },
        {
            "role": "user",
            "content": build_judge_user_prompt(question, gt, response),
        },
    ]

    last_error = None
    started = time.perf_counter()

    for attempt in range(MAX_RETRIES):
        try:
            # First choice: vLLM guided JSON.
            try:
                completion = client.chat.completions.create(
                    model=MODEL_NAME,
                    messages=messages,
                    temperature=JUDGE_TEMPERATURE,
                    max_tokens=JUDGE_MAX_TOKENS,
                    extra_body={
                        "guided_json": JUDGE_JSON_SCHEMA,
                    },
                )

            except Exception:
                # Fallback: OpenAI-style JSON mode.
                completion = client.chat.completions.create(
                    model=MODEL_NAME,
                    messages=messages,
                    temperature=JUDGE_TEMPERATURE,
                    max_tokens=JUDGE_MAX_TOKENS,
                    response_format={"type": "json_object"},
                )

            raw_text = completion.choices[0].message.content or ""
            parsed = normalize_judge_output(extract_first_json_object(raw_text))

            latency = time.perf_counter() - started

            return {
                "judge_reason": parsed["reason"],
                "judge_score": parsed["score"],
                "judge_raw": raw_text,
                "judge_error": None,
                "judge_latency_sec": latency,
            }

        except Exception as e:
            last_error = repr(e)
            time.sleep(2.0 * (attempt + 1))

    latency = time.perf_counter() - started

    return {
        "judge_reason": None,
        "judge_score": None,
        "judge_raw": None,
        "judge_error": last_error,
        "judge_latency_sec": latency,
    }

# %%
#cell 10
# Judge one file with resume support and automatic rejudging of failed rows.
from concurrent.futures import ThreadPoolExecutor, as_completed
from tqdm.auto import tqdm
from pathlib import Path
from typing import Dict, Any
import json

REQUEST_CONCURRENCY = 16
FILE_MAX_ROUNDS = 5

# Keep the notebook moving so the repair cell can fix any remaining malformed outputs.
RAISE_ON_FAILED_JUDGEMENTS = False

def make_result_key(record: Dict[str, Any], row_id: int) -> str:
    # Make a stable key.
    if record.get("source_index") is not None:
        return str(record.get("source_index"))

    return str(row_id)

def is_valid_judgement(obj: Dict[str, Any] | None) -> bool:
    # Check if a saved judgement is usable.
    if obj is None:
        return False

    if obj.get("judge_error") is not None:
        return False

    if obj.get("judge_score") not in {0, 1}:
        return False

    return True

def load_existing_jsonl(path: Path) -> Dict[str, Dict[str, Any]]:
    # Load latest result for each key.
    existing = {}

    if not path.exists():
        return existing

    with open(path, "r", encoding="utf-8") as f:
        for line in f:
            line = line.strip()

            if not line:
                continue

            try:
                obj = json.loads(line)
            except Exception:
                continue

            key = str(obj.get("_judge_key"))
            existing[key] = obj

    return existing

def append_jsonl(path: Path, obj: Dict[str, Any]):
    # Append one JSONL row.
    with open(path, "a", encoding="utf-8") as f:
        f.write(json.dumps(obj, ensure_ascii=False) + "\n")

def judge_file(input_file_name: str) -> Path:
    # Judge all rows in one file.
    data = all_input_data[input_file_name]

    stem = Path(input_file_name).stem
    out_jsonl = GDRIVE_OUTPUT_DIR / f"{stem}__judged.jsonl"
    out_json = GDRIVE_OUTPUT_DIR / f"{stem}__judged.json"

    for round_id in range(1, FILE_MAX_ROUNDS + 1):
        existing = load_existing_jsonl(out_jsonl)

        todo = []

        for row_id, record in enumerate(data):
            key = make_result_key(record, row_id)
            current = existing.get(key)

            # Rejudge missing or failed rows.
            if not is_valid_judgement(current):
                todo.append((row_id, key, record))

        print("\nFile:", input_file_name)
        print("Round:", round_id)
        print("Rows:", len(data))
        print("Valid already judged:", len(data) - len(todo))
        print("Remaining or failed:", len(todo))

        if not todo:
            break

        with ThreadPoolExecutor(max_workers=REQUEST_CONCURRENCY) as executor:
            futures = {
                executor.submit(judge_one_record, record): (row_id, key, record)
                for row_id, key, record in todo
            }

            for future in tqdm(
                as_completed(futures),
                total=len(futures),
                desc=f"Judging {input_file_name} | round {round_id}",
            ):
                row_id, key, record = futures[future]
                judge_result = future.result()

                out_obj = {
                    "_judge_key": key,
                    "_row_id": row_id,
                    "_input_file": input_file_name,

                    "source_index": record.get("source_index"),
                    "type": record.get("type"),
                    "question": record.get("question"),
                    "gt": record.get("gt"),
                    "response": record.get("response"),

                    "attempt": record.get("attempt"),
                    "max_tokens_used": record.get("max_tokens_used"),
                    "completion_tokens": record.get("completion_tokens"),
                    "retry_reason": record.get("retry_reason"),

                    **judge_result,
                }

                append_jsonl(out_jsonl, out_obj)

    # Reload after all rounds.
    existing = load_existing_jsonl(out_jsonl)

    ordered = []

    for row_id, record in enumerate(data):
        key = make_result_key(record, row_id)

        if key not in existing:
            raise RuntimeError(f"Missing judgement for key={key} in {input_file_name}")

        ordered.append(existing[key])

    failed = [
        x for x in ordered
        if not is_valid_judgement(x)
    ]

    print("Final failed judgements:", len(failed))

    if failed and RAISE_ON_FAILED_JUDGEMENTS:
        print("First failed judgement:")
        print(json.dumps(failed[0], ensure_ascii=False, indent=2)[:2000])
        raise RuntimeError(
            f"{len(failed)} failed judgements remain in {input_file_name}. "
            f"Re-run this cell or reduce REQUEST_CONCURRENCY."
        )

    if failed:
        print("First failed judgement:")
        print(json.dumps(failed[0], ensure_ascii=False, indent=2)[:2000])
        print("Run the repair cell before computing final accuracy.")

    with open(out_json, "w", encoding="utf-8") as f:
        json.dump(ordered, f, ensure_ascii=False, indent=2)

    print("Saved JSONL:", out_jsonl)
    print("Saved JSON:", out_json)

    return out_json

# %%
#cell 11
# Run judge for all files.
judged_json_paths = []

for input_file_name in INPUT_FILES:
    judged_path = judge_file(input_file_name)
    judged_json_paths.append(judged_path)

print("\nAll files judged.")
print("Run cell 11.5 next to repair any remaining failed or malformed judgements.")

for path in judged_json_paths:
    print(path)
# Out:
# File: 2wikimultihopqa_answer_qwen3.5.json
# Round: 1
# Rows: 1000
# Valid already judged: 0
# Remaining or failed: 1000
# Judging 2wikimultihopqa_answer_qwen3.5.json | round 1:   0%|          | 0/1000 [00:00<?, ?it/s]
# File: 2wikimultihopqa_answer_qwen3.5.json
# Round: 2
# Rows: 1000
# Valid already judged: 1000
# Remaining or failed: 0
# Final failed judgements: 0
# Saved JSONL: /content/drive/MyDrive/final_project/idea_1/answers/2wikimultihopqa/llm_judge_qwen35_27b/2wikimultihopqa_answer_qwen3.5__judged.jsonl
# Saved JSON: /content/drive/MyDrive/final_project/idea_1/answers/2wikimultihopqa/llm_judge_qwen35_27b/2wikimultihopqa_answer_qwen3.5__judged.json
#
# File: 2wikimultihopqa_answer_gpt_oss.json
# Round: 1
# Rows: 1000
# Valid already judged: 0
# Remaining or failed: 1000
# Judging 2wikimultihopqa_answer_gpt_oss.json | round 1:   0%|          | 0/1000 [00:00<?, ?it/s]
# File: 2wikimultihopqa_answer_gpt_oss.json
# Round: 2
# Rows: 1000
# Valid already judged: 1000
# Remaining or failed: 0
# Final failed judgements: 0
# Saved JSONL: /content/drive/MyDrive/final_project/idea_1/answers/2wikimultihopqa/llm_judge_qwen35_27b/2wikimultihopqa_answer_gpt_oss__judged.jsonl
# Saved JSON: /content/drive/MyDrive/final_project/idea_1/answers/2wikimultihopqa/llm_judge_qwen35_27b/2wikimultihopqa_answer_gpt_oss__judged.json
#
# File: 2wikimultihopqa_answer_gemma4.json
# Round: 1
# Rows: 1000
# Valid already judged: 0
# Remaining or failed: 1000
# Judging 2wikimultihopqa_answer_gemma4.json | round 1:   0%|          | 0/1000 [00:00<?, ?it/s]
# File: 2wikimultihopqa_answer_gemma4.json
# Round: 2
# Rows: 1000
# Valid already judged: 1000
# Remaining or failed: 0
# Final failed judgements: 0
# Saved JSONL: /content/drive/MyDrive/final_project/idea_1/answers/2wikimultihopqa/llm_judge_qwen35_27b/2wikimultihopqa_answer_gemma4__judged.jsonl
# Saved JSON: /content/drive/MyDrive/final_project/idea_1/answers/2wikimultihopqa/llm_judge_qwen35_27b/2wikimultihopqa_answer_gemma4__judged.json
#
# All files judged.
# Run cell 11.5 next to repair any remaining failed or malformed judgements.
# /content/drive/MyDrive/final_project/idea_1/answers/2wikimultihopqa/llm_judge_qwen35_27b/2wikimultihopqa_answer_qwen3.5__judged.json
# /content/drive/MyDrive/final_project/idea_1/answers/2wikimultihopqa/llm_judge_qwen35_27b/2wikimultihopqa_answer_gpt_oss__judged.json
# /content/drive/MyDrive/final_project/idea_1/answers/2wikimultihopqa/llm_judge_qwen35_27b/2wikimultihopqa_answer_gemma4__judged.json

# %%
#cell 11.5
# Repair failed judgements before loading final results.
import re
import json
import time
from pathlib import Path
from tqdm.auto import tqdm

REPAIR_MAX_RETRIES = 3
REPAIR_MAX_TOKENS = 128
REPAIR_TEMPERATURE = 0.0

REPAIR_SYSTEM_PROMPT = """
You are a strict but fair answer judge.

You will receive:
- a question
- the ground-truth answer
- a candidate LLM response

Judge whether the candidate response correctly answers the question.
Use the ground-truth answer as the authoritative answer.
Do not solve the question yourself.

Return exactly two lines:
reason: short reason without quotation marks
score: 0 or 1

Rules:
- Score 1 if the candidate gives the correct answer.
- Score 1 if the candidate is semantically the same as the ground truth.
- Score 1 if extra information is present but not contradictory.
- Score 1 if the candidate gives the main requested answer clearly and any missing part is only a harmless clarifying suffix.
- Score 0 if the candidate is wrong, incomplete, vague, too broad, or too narrow.
- Score 0 if the candidate says unknown, unavailable, cannot be determined, or similar.
- Score 0 if there is contradiction or an incorrect final answer.
- When unsure, score 0.
""".strip()

def build_repair_prompt(question: str, gt: str, response: str) -> str:
    # Build repair judge prompt.
    return f"""
Question:
{question}

Ground-truth answer:
{gt}

Candidate LLM response:
{response}

Return exactly:
reason: ...
score: 0 or 1
""".strip()

def parse_repair_output(text: str):
    # Parse score and reason from plain text.
    text = (text or "").strip()

    score_match = re.search(r"(?im)^\s*score\s*:\s*([01])\s*$", text)

    if score_match is None:
        score_match = re.search(r"(?i)\bscore\s*[:=]\s*([01])\b", text)

    if score_match is None:
        raise ValueError(f"Could not parse score from: {text[:300]}")

    score = int(score_match.group(1))

    reason_match = re.search(r"(?im)^\s*reason\s*:\s*(.+?)\s*$", text)
    reason = reason_match.group(1).strip() if reason_match else "Parsed score from repair judge."

    reason = reason.replace('"', "'")
    reason = " ".join(reason.split())

    if not reason:
        reason = "No reason provided."

    return {
        "judge_reason": reason,
        "judge_score": score,
        "judge_raw": text,
        "judge_error": None,
    }

def repair_judge_one_record(record):
    # Rejudge one failed row with plain-text output.
    question = str(record.get("question", ""))
    gt = str(record.get("gt", ""))
    response = str(record.get("response", ""))

    messages = [
        {
            "role": "system",
            "content": REPAIR_SYSTEM_PROMPT,
        },
        {
            "role": "user",
            "content": build_repair_prompt(question, gt, response),
        },
    ]

    last_error = None
    started = time.perf_counter()

    for attempt in range(REPAIR_MAX_RETRIES):
        try:
            completion = client.chat.completions.create(
                model=MODEL_NAME,
                messages=messages,
                temperature=REPAIR_TEMPERATURE,
                max_tokens=REPAIR_MAX_TOKENS,
            )

            raw_text = completion.choices[0].message.content or ""
            parsed = parse_repair_output(raw_text)

            parsed["judge_latency_sec"] = time.perf_counter() - started
            return parsed

        except Exception as e:
            last_error = repr(e)
            time.sleep(1.5 * (attempt + 1))

    # Final safety fallback.
    return {
        "judge_reason": "Repair failed after retries; defaulted to incorrect.",
        "judge_score": 0,
        "judge_raw": None,
        "judge_error": None,
        "judge_latency_sec": time.perf_counter() - started,
    }

def load_latest_jsonl(path: Path):
    # Load latest row for each key.
    latest = {}

    if not path.exists():
        return latest

    with open(path, "r", encoding="utf-8") as f:
        for line in f:
            line = line.strip()

            if not line:
                continue

            try:
                obj = json.loads(line)
            except Exception:
                continue

            latest[str(obj.get("_judge_key"))] = obj

    return latest

def valid_judgement(obj):
    # Check valid judgement.
    if obj is None:
        return False

    if obj.get("judge_error") is not None:
        return False

    if obj.get("judge_score") not in {0, 1}:
        return False

    return True

def append_jsonl_row(path: Path, obj):
    # Append repaired row.
    with open(path, "a", encoding="utf-8") as f:
        f.write(json.dumps(obj, ensure_ascii=False) + "\n")

judged_json_paths = []

for input_file_name in INPUT_FILES:
    data = all_input_data[input_file_name]

    stem = Path(input_file_name).stem
    out_jsonl = GDRIVE_OUTPUT_DIR / f"{stem}__judged.jsonl"
    out_json = GDRIVE_OUTPUT_DIR / f"{stem}__judged.json"

    latest = load_latest_jsonl(out_jsonl)

    failed_items = []

    for row_id, record in enumerate(data):
        key = make_result_key(record, row_id)
        current = latest.get(key)

        if not valid_judgement(current):
            failed_items.append((row_id, key, record, current))

    print("\nFile:", input_file_name)
    print("Failed or missing before repair:", len(failed_items))

    for row_id, key, record, old_obj in tqdm(failed_items, desc=f"Repairing {input_file_name}"):
        repair_result = repair_judge_one_record(record)

        repaired_obj = {
            "_judge_key": key,
            "_row_id": row_id,
            "_input_file": input_file_name,

            "source_index": record.get("source_index"),
            "type": record.get("type"),
            "question": record.get("question"),
            "gt": record.get("gt"),
            "response": record.get("response"),

            "attempt": record.get("attempt"),
            "max_tokens_used": record.get("max_tokens_used"),
            "completion_tokens": record.get("completion_tokens"),
            "retry_reason": record.get("retry_reason"),

            **repair_result,
        }

        append_jsonl_row(out_jsonl, repaired_obj)
        latest[key] = repaired_obj

    # Build ordered final JSON.
    ordered = []

    for row_id, record in enumerate(data):
        key = make_result_key(record, row_id)
        obj = latest.get(key)

        if not valid_judgement(obj):
            # Last safety fallback.
            obj = {
                "_judge_key": key,
                "_row_id": row_id,
                "_input_file": input_file_name,

                "source_index": record.get("source_index"),
                "type": record.get("type"),
                "question": record.get("question"),
                "gt": record.get("gt"),
                "response": record.get("response"),

                "attempt": record.get("attempt"),
                "max_tokens_used": record.get("max_tokens_used"),
                "completion_tokens": record.get("completion_tokens"),
                "retry_reason": record.get("retry_reason"),

                "judge_reason": "Final fallback after repair failure; defaulted to incorrect.",
                "judge_score": 0,
                "judge_raw": None,
                "judge_error": None,
                "judge_latency_sec": None,
            }

            append_jsonl_row(out_jsonl, obj)
            latest[key] = obj

        ordered.append(obj)

    final_failed = [x for x in ordered if not valid_judgement(x)]

    print("Failed after repair:", len(final_failed))

    with open(out_json, "w", encoding="utf-8") as f:
        json.dump(ordered, f, ensure_ascii=False, indent=2)

    print("Saved final JSON:", out_json)

    judged_json_paths.append(out_json)

print("\nRepair complete. Now run cell 12.")
for path in judged_json_paths:
    print(path)
# Out:
# File: 2wikimultihopqa_answer_qwen3.5.json
# Failed or missing before repair: 0
# Repairing 2wikimultihopqa_answer_qwen3.5.json: 0it [00:00, ?it/s]
# Failed after repair: 0
# Saved final JSON: /content/drive/MyDrive/final_project/idea_1/answers/2wikimultihopqa/llm_judge_qwen35_27b/2wikimultihopqa_answer_qwen3.5__judged.json
#
# File: 2wikimultihopqa_answer_gpt_oss.json
# Failed or missing before repair: 0
# Repairing 2wikimultihopqa_answer_gpt_oss.json: 0it [00:00, ?it/s]
# Failed after repair: 0
# Saved final JSON: /content/drive/MyDrive/final_project/idea_1/answers/2wikimultihopqa/llm_judge_qwen35_27b/2wikimultihopqa_answer_gpt_oss__judged.json
#
# File: 2wikimultihopqa_answer_gemma4.json
# Failed or missing before repair: 0
# Repairing 2wikimultihopqa_answer_gemma4.json: 0it [00:00, ?it/s]
# Failed after repair: 0
# Saved final JSON: /content/drive/MyDrive/final_project/idea_1/answers/2wikimultihopqa/llm_judge_qwen35_27b/2wikimultihopqa_answer_gemma4__judged.json
#
# Repair complete. Now run cell 12.
# /content/drive/MyDrive/final_project/idea_1/answers/2wikimultihopqa/llm_judge_qwen35_27b/2wikimultihopqa_answer_qwen3.5__judged.json
# /content/drive/MyDrive/final_project/idea_1/answers/2wikimultihopqa/llm_judge_qwen35_27b/2wikimultihopqa_answer_gpt_oss__judged.json
# /content/drive/MyDrive/final_project/idea_1/answers/2wikimultihopqa/llm_judge_qwen35_27b/2wikimultihopqa_answer_gemma4__judged.json

# %%
#cell 12
# Load all judged outputs.
import pandas as pd
import json

rows = []

for path in judged_json_paths:
    with open(path, "r", encoding="utf-8") as f:
        data = json.load(f)

    rows.extend(data)

df = pd.DataFrame(rows)

df["judge_score"] = pd.to_numeric(df["judge_score"], errors="coerce")

print("Total rows:", len(df))
print("Files:", df["_input_file"].nunique())
print("Invalid judgements:", df["judge_score"].isna().sum())

display(df.head())
# Out:
# Total rows: 3000
# Files: 3
# Invalid judgements: 0
#   _judge_key  _row_id                          _input_file  source_index  \
# 0          0        0  2wikimultihopqa_answer_qwen3.5.json             0
# 1          1        1  2wikimultihopqa_answer_qwen3.5.json             1
# 2          2        2  2wikimultihopqa_answer_qwen3.5.json             2
# 3          3        3  2wikimultihopqa_answer_qwen3.5.json             3
# 4          4        4  2wikimultihopqa_answer_qwen3.5.json             4
#
#          type                                           question  \
# 0  comparison  Are North Marion High School (Oregon) and Seou...
# 1  comparison  Are Fire In Hell and The Tiger: An Old Hunter'...
# 2  comparison  Are Simonds Catholic College and Saginaw High ...
# 3  comparison  Who was born first, John Beach or Gordon Persons?
# 4  comparison  Who is older, Aryeh Ben-Eliezer or Jason Pociask?
#
#                   gt                           response  attempt  \
# 0                 no                                 No        1
# 1                yes  Yes, both are South Korean films.        0
# 2                 no                                 No        1
# 3         John Beach                         John Beach        0
# 4  Aryeh Ben-Eliezer                  Aryeh Ben-Eliezer        0
#
#    max_tokens_used  completion_tokens retry_reason  \
# 0            81920                801         None
# 1            32768               1001         None
# 2            81920               1060         None
# 3            32768               1565         None
# 4            32768                385         None
#
#                                         judge_reason  judge_score  \
# 0  The candidate response matches the ground trut...            1
# 1  The candidate correctly answers yes and provid...            1
# 2  The candidate response matches the ground trut...            1
# 3  The candidate response matches the ground trut...            1
# 4  The candidate response matches the ground trut...            1
#
#                                            judge_raw judge_error  \
# 0  {\n  "reason": "The candidate response matches...        None
# 1  {\n  "reason": "The candidate correctly answer...        None
# 2  {\n  "reason": "The candidate response matches...        None
# 3  {\n  "reason": "The candidate response matches...        None
# 4  {\n  "reason": "The candidate response matches...        None
#
#    judge_latency_sec
# 0          25.182766
# 1          25.675282
# 2          23.923796
# 3          23.613953
# 4          24.218588

# %%
#cell 13
# Compute accuracy overall and by type.
valid_df = df[df["judge_score"].isin([0, 1])].copy()

if len(valid_df) != len(df):
    raise RuntimeError("Some judgements are invalid. Fix them before computing accuracy.")

def accuracy_table(dataframe, group_cols):
    # Build accuracy table.
    result = (
        dataframe
        .groupby(group_cols, dropna=False)
        .agg(
            total=("judge_score", "size"),
            correct=("judge_score", "sum"),
            accuracy=("judge_score", "mean"),
        )
        .reset_index()
    )

    result["correct"] = result["correct"].astype(int)
    result["accuracy_percent"] = result["accuracy"] * 100.0

    return result.sort_values(group_cols).reset_index(drop=True)

per_file_overall = accuracy_table(valid_df, ["_input_file"])
per_file_type = accuracy_table(valid_df, ["_input_file", "type"])
combined_type = accuracy_table(valid_df, ["type"])

combined_overall = pd.DataFrame([
    {
        "scope": "all_files_combined",
        "total": int(valid_df["judge_score"].size),
        "correct": int(valid_df["judge_score"].sum()),
        "accuracy": float(valid_df["judge_score"].mean()),
        "accuracy_percent": float(valid_df["judge_score"].mean() * 100.0),
    }
])

print("Per-file overall accuracy:")
display(per_file_overall)

print("Per-file per-type accuracy:")
display(per_file_type)

print("Combined per-type accuracy:")
display(combined_type)

print("Combined overall accuracy:")
display(combined_overall)
# Out:
# Per-file overall accuracy:
#                            _input_file  total  correct  accuracy  \
# 0   2wikimultihopqa_answer_gemma4.json   1000      919     0.919
# 1  2wikimultihopqa_answer_gpt_oss.json   1000      915     0.915
# 2  2wikimultihopqa_answer_qwen3.5.json   1000      862     0.862
#
#    accuracy_percent
# 0              91.9
# 1              91.5
# 2              86.2
# Per-file per-type accuracy:
#                             _input_file               type  total  correct  \
# 0    2wikimultihopqa_answer_gemma4.json  bridge_comparison    250      246
# 1    2wikimultihopqa_answer_gemma4.json         comparison    250      244
# 2    2wikimultihopqa_answer_gemma4.json      compositional    250      193
# 3    2wikimultihopqa_answer_gemma4.json          inference    250      236
# 4   2wikimultihopqa_answer_gpt_oss.json  bridge_comparison    250      242
# 5   2wikimultihopqa_answer_gpt_oss.json         comparison    250      247
# 6   2wikimultihopqa_answer_gpt_oss.json      compositional    250      193
# 7   2wikimultihopqa_answer_gpt_oss.json          inference    250      233
# 8   2wikimultihopqa_answer_qwen3.5.json  bridge_comparison    250      242
# 9   2wikimultihopqa_answer_qwen3.5.json         comparison    250      240
# 10  2wikimultihopqa_answer_qwen3.5.json      compositional    250      193
# 11  2wikimultihopqa_answer_qwen3.5.json          inference    250      187
#
#     accuracy  accuracy_percent
# 0      0.984              98.4
# 1      0.976              97.6
# 2      0.772              77.2
# 3      0.944              94.4
# 4      0.968              96.8
# 5      0.988              98.8
# 6      0.772              77.2
# 7      0.932              93.2
# 8      0.968              96.8
# 9      0.960              96.0
# 10     0.772              77.2
# 11     0.748              74.8
# Combined per-type accuracy:
#                 type  total  correct  accuracy  accuracy_percent
# 0  bridge_comparison    750      730  0.973333         97.333333
# 1         comparison    750      731  0.974667         97.466667
# 2      compositional    750      579  0.772000         77.200000
# 3          inference    750      656  0.874667         87.466667
# Combined overall accuracy:
#                 scope  total  correct  accuracy  accuracy_percent
# 0  all_files_combined   3000     2696  0.898667         89.866667

# %%
#cell 15
# Inspect rejected answers.
N_EXAMPLES = 30

rejected = valid_df[valid_df["judge_score"] == 0].copy()

cols = [
    "_input_file",
    "source_index",
    "type",
    "question",
    "gt",
    "response",
    "judge_reason",
]

print("Rejected rows:", len(rejected))
display(rejected[cols].head(N_EXAMPLES))
# Out:
# Rejected rows: 304
#                              _input_file  source_index        type  \
# 30   2wikimultihopqa_answer_qwen3.5.json            30  comparison
# 41   2wikimultihopqa_answer_qwen3.5.json            41  comparison
# 70   2wikimultihopqa_answer_qwen3.5.json            70  comparison
# 85   2wikimultihopqa_answer_qwen3.5.json            85  comparison
# 104  2wikimultihopqa_answer_qwen3.5.json           104  comparison
# 139  2wikimultihopqa_answer_qwen3.5.json           139  comparison
# 197  2wikimultihopqa_answer_qwen3.5.json           197  comparison
# 226  2wikimultihopqa_answer_qwen3.5.json           226  comparison
# 227  2wikimultihopqa_answer_qwen3.5.json           227  comparison
# 243  2wikimultihopqa_answer_qwen3.5.json           243  comparison
# 255  2wikimultihopqa_answer_qwen3.5.json           255   inference
# 262  2wikimultihopqa_answer_qwen3.5.json           262   inference
# 263  2wikimultihopqa_answer_qwen3.5.json           263   inference
# 265  2wikimultihopqa_answer_qwen3.5.json           265   inference
# 266  2wikimultihopqa_answer_qwen3.5.json           266   inference
# 267  2wikimultihopqa_answer_qwen3.5.json           267   inference
# 270  2wikimultihopqa_answer_qwen3.5.json           270   inference
# 273  2wikimultihopqa_answer_qwen3.5.json           273   inference
# 283  2wikimultihopqa_answer_qwen3.5.json           283   inference
# 285  2wikimultihopqa_answer_qwen3.5.json           285   inference
# 288  2wikimultihopqa_answer_qwen3.5.json           288   inference
# 292  2wikimultihopqa_answer_qwen3.5.json           292   inference
# 294  2wikimultihopqa_answer_qwen3.5.json           294   inference
# 298  2wikimultihopqa_answer_qwen3.5.json           298   inference
# 301  2wikimultihopqa_answer_qwen3.5.json           301   inference
# 310  2wikimultihopqa_answer_qwen3.5.json           310   inference
# 312  2wikimultihopqa_answer_qwen3.5.json           312   inference
# 313  2wikimultihopqa_answer_qwen3.5.json           313   inference
# 332  2wikimultihopqa_answer_qwen3.5.json           332   inference
# 333  2wikimultihopqa_answer_qwen3.5.json           333   inference
#
#                                               question  \
# 30   Are Walter E. Massey and Matt Horwich both fro...
# 41   Who lived longer, Gustav Philipp Mörl or Giuse...
# 70   Who died earlier, Roza Robota or Giovanni Cagl...
# 85   Who lived longer, Les Sille or William Grant S...
# 104  Who lived longer, Russ Prior or Robert Von Zim...
# 139  Are Joseph Zaretzki and Phil Torres from the s...
# 197  Who lived longer, Ole Arntzen or Harry Albert ...
# 226  Are both movies, National Lampoon'S Dorm Daze ...
# 227  Who died earlier, John Lysaght, 1St Baron Lisl...
# 243  Are both movies, Crossing The Line 2: The New ...
# 255    Who is the father-in-law of Tsandzile Ndwandwe?
# 262  Who is the paternal grandmother of Sudeley Han...
# 263  Who is Archibald Acheson, 4Th Earl Of Gosford'...
# 265                 Who is Wang Xijie's father-in-law?
# 266  Who is the maternal grandfather of Prince Dmit...
# 267  Who is Prince Harald Of Schaumburg-Lippe's mat...
# 270  Who is the paternal grandmother of Charles Stu...
# 273  Who is the paternal grandfather of Sultan Al-D...
# 283  Who is the paternal grandfather of William De ...
# 285  Who is Joan De Beauchamp, Countess Of Ormond's...
# 288     Who is the father-in-law of Rahmat Banu Begum?
# 292     Who is the father-in-law of Lady Rose Mclaren?
# 294  Who is the paternal grandfather of Richard Whi...
# 298  Who is Princess Adelaide Of Saxe-Meiningen's m...
# 301  Who is the paternal grandfather of King Zhao O...
# 310  Who is the maternal grandmother of Henry Of Na...
# 312  Who is the maternal grandfather of Count Micha...
# 313  Who is the paternal grandfather of Bernhard Vi...
# 332  Who is the paternal grandmother of Princess El...
# 333          Who is the father-in-law of Halime Hatun?
#
#                                                     gt  \
# 30                                                 yes
# 41                                 Gustav Philipp Mörl
# 70                                   Giovanni Cagliero
# 85                                 William Grant Still
# 104                              Robert Von Zimmermann
# 139                                                yes
# 197                                Harry Albert Willis
# 226                                                yes
# 227                      John Lysaght, 1St Baron Lisle
# 243                                                yes
# 255                                         Ndvungunye
# 262                            Henrietta Susanna Tracy
# 263             Archibald Acheson, 2nd Earl of Gosford
# 265                                           Longqing
# 266                            Alexander III of Russia
# 267                           Prince Harald of Denmark
# 270                                  Elizabeth Stewart
# 273                                     'Adud al-Dawla
# 283               Robert de Ferrers, 2nd Earl of Derby
# 285                   James Butler, 3rd Earl of Ormond
# 288                                          Aurangzeb
# 292                                      Henry McLaren
# 294                                        Simon White
# 298                           Karoline of Wartensleben
# 301                                    King Hui of Wei
# 310                        Anna of Eppstein-Königstein
# 312                  Prince Nikolaus Wilhelm of Nassau
# 313                  Ernest I, Prince of Anhalt-Dessau
# 332  Duchess Charlotte Georgine of Mecklenburg-Stre...
# 333                                      Suleyman Shah
#
#                                               response  \
# 30                                                  No
# 41                       Giuseppe Diotti lived longer.
# 70                                         Roza Robota
# 85                                           Les Sille
# 104                           Russ Prior lived longer.
# 139            No, they are not from the same country.
# 197                                        Ole Arntzen
# 226                                                 No
# 227                                        Arne Laurin
# 243                          Information not available
# 255                                          Sobhuza I
# 262                                    Susannah Weaver
# 263                Arthur Acheson, 1st Earl of Gosford
# 265                          Information not available
# 266                                  Tsar Alexander II
# 267  Friedrich Ferdinand, Duke of Schleswig-Holstei...
# 270                          Information not available
# 273                                      Rukn al-Dawla
# 283               Robert de Ferrers, 1st Earl of Derby
# 285                   John de Welles, 4th Baron Welles
# 288                              Momai Tamuli Borbarua
# 292            Charles Paget, 6th Marquess of Anglesey
# 294                                      Richard White
# 298               Countess Adelheid of Castell-Castell
# 301                                 Marquess Wu of Wei
# 310                          Information not available
# 312                                  Alexander Pushkin
# 313                  George I, Prince of Anhalt-Dessau
# 332             Princess Friederike of Hesse-Darmstadt
# 333                          Information not available
#
#                                           judge_reason
# 30   The candidate answered No, but the ground trut...
# 41   The candidate incorrectly states Giuseppe Diot...
# 70   The candidate incorrectly identified Roza Robo...
# 85   The candidate incorrectly identified Les Sille...
# 104  The candidate incorrectly states Russ Prior li...
# 139  The candidate response contradicts the ground ...
# 197  The candidate answered Ole Arntzen, but the gr...
# 226  The candidate answered No, but the ground trut...
# 227  The candidate answered Arne Laurin, but the gr...
# 243  The candidate claims information is unavailabl...
# 255  The candidate answer Sobhuza I is incorrect; t...
# 262  The candidate response provides a different na...
# 263  The candidate incorrectly identifies the pater...
# 265  The candidate claims information is unavailabl...
# 266  The candidate incorrectly identifies Alexander...
# 267  The candidate response provides a different na...
# 270  The candidate claims information is unavailabl...
# 273  The candidate response Rukn al-Dawla is incorr...
# 283  The candidate incorrectly identifies the grand...
# 285  The candidate response provides a different na...
# 288  The candidate response is incorrect; the groun...
# 292  The candidate response provides a different na...
# 294  The candidate incorrectly identifies the subje...
# 298  The candidate provided the wrong name; the gro...
# 301  The candidate answer Marquess Wu of Wei is inc...
# 310  The candidate claims information is unavailabl...
# 312  The candidate answer Alexander Pushkin is inco...
# 313  The candidate incorrectly identifies the grand...
# 332  The candidate response provides a different na...
# 333  The candidate claims information is unavailabl...

# %%
#cell 16
# Inspect accepted answers.
N_EXAMPLES = 30

accepted = valid_df[valid_df["judge_score"] == 1].copy()

cols = [
    "_input_file",
    "source_index",
    "type",
    "question",
    "gt",
    "response",
    "judge_reason",
]

print("Accepted rows:", len(accepted))
display(accepted[cols].head(N_EXAMPLES))
# Out:
# Accepted rows: 2696
#                             _input_file  source_index        type  \
# 0   2wikimultihopqa_answer_qwen3.5.json             0  comparison
# 1   2wikimultihopqa_answer_qwen3.5.json             1  comparison
# 2   2wikimultihopqa_answer_qwen3.5.json             2  comparison
# 3   2wikimultihopqa_answer_qwen3.5.json             3  comparison
# 4   2wikimultihopqa_answer_qwen3.5.json             4  comparison
# 5   2wikimultihopqa_answer_qwen3.5.json             5  comparison
# 6   2wikimultihopqa_answer_qwen3.5.json             6  comparison
# 7   2wikimultihopqa_answer_qwen3.5.json             7  comparison
# 8   2wikimultihopqa_answer_qwen3.5.json             8  comparison
# 9   2wikimultihopqa_answer_qwen3.5.json             9  comparison
# 10  2wikimultihopqa_answer_qwen3.5.json            10  comparison
# 11  2wikimultihopqa_answer_qwen3.5.json            11  comparison
# 12  2wikimultihopqa_answer_qwen3.5.json            12  comparison
# 13  2wikimultihopqa_answer_qwen3.5.json            13  comparison
# 14  2wikimultihopqa_answer_qwen3.5.json            14  comparison
# 15  2wikimultihopqa_answer_qwen3.5.json            15  comparison
# 16  2wikimultihopqa_answer_qwen3.5.json            16  comparison
# 17  2wikimultihopqa_answer_qwen3.5.json            17  comparison
# 18  2wikimultihopqa_answer_qwen3.5.json            18  comparison
# 19  2wikimultihopqa_answer_qwen3.5.json            19  comparison
# 20  2wikimultihopqa_answer_qwen3.5.json            20  comparison
# 21  2wikimultihopqa_answer_qwen3.5.json            21  comparison
# 22  2wikimultihopqa_answer_qwen3.5.json            22  comparison
# 23  2wikimultihopqa_answer_qwen3.5.json            23  comparison
# 24  2wikimultihopqa_answer_qwen3.5.json            24  comparison
# 25  2wikimultihopqa_answer_qwen3.5.json            25  comparison
# 26  2wikimultihopqa_answer_qwen3.5.json            26  comparison
# 27  2wikimultihopqa_answer_qwen3.5.json            27  comparison
# 28  2wikimultihopqa_answer_qwen3.5.json            28  comparison
# 29  2wikimultihopqa_answer_qwen3.5.json            29  comparison
#
#                                              question  \
# 0   Are North Marion High School (Oregon) and Seou...
# 1   Are Fire In Hell and The Tiger: An Old Hunter'...
# 2   Are Simonds Catholic College and Saginaw High ...
# 3   Who was born first, John Beach or Gordon Persons?
# 4   Who is older, Aryeh Ben-Eliezer or Jason Pociask?
# 5   Are Tomskoye, Amur Oblast and Pleshkovo locate...
# 6   Which one was established first, Noerr or Korn...
# 7   Which film came out earlier, Dis-Moi Qui Tuer ...
# 8   Which film was released more recently, Toolbox...
# 9   Which film was released earlier, Premium (Film...
# 10  Are both Țerova and Slava (River) located in t...
# 11  Are Elsah, Illinois and Chah-E Puzeh, Tabas bo...
# 12  Who lived longer, Csaba Pálinkás or Henry Sche...
# 13  Which film was released more recently, Pirates...
# 14  Which film was released earlier, Anna-Liisa or...
# 15  Who was born first out of Alexey Volkonsky and...
# 16  Who was born first out of Ramsay Anderson and ...
# 17  Who died first, Olaf Everson or Abdul Wahab Kh...
# 18  Who was born first out of Overill Dwyer-Brown ...
# 19  Which film was released first, Heaven Help Us ...
# 20  Who lived longer, Louis-Armand-Constantin De R...
# 21  Who was born first, Emmanuel Goffi or Mariano ...
# 22  Who was born later, Bradley Tyler Johnson or B...
# 23  Which film came out first, Poznań '56 or The L...
# 24  Who was born later, Ramón Corona or Ernest Wil...
# 25  Are Les Misérables (1917 Film) and The Better ...
# 26  Who was born first out of Pierre Gauvreau and ...
# 27    Who was born first, Patrik Lácha or Brad Booth?
# 28  Which film was released more recently, Horas M...
# 29  Are Car Trouble (Film) and White Heat (1926 Fi...
#
#                                          gt  \
# 0                                        no
# 1                                       yes
# 2                                        no
# 3                                John Beach
# 4                         Aryeh Ben-Eliezer
# 5                                       yes
# 6                                     Noerr
# 7                          Dis-Moi Qui Tuer
# 8                           Toolbox Murders
# 9                      Week-End With Father
# 10                                      yes
# 11                                       no
# 12                            Henry Scheffé
# 13                             Alien Origin
# 14                               Anna-Liisa
# 15                       Wanderley Oliveira
# 16                          Ramsay Anderson
# 17                   Abdul Wahab Khan Tarzi
# 18                      Overill Dwyer-Brown
# 19                             Ghar Ki Rani
# 20             Adalberto Pereira Dos Santos
# 21                           Emmanuel Goffi
# 22                         Bernardo Freitas
# 23  The Last Day Of School Before Christmas
# 24               Ernest William Goodpasture
# 25                                      yes
# 26                        Tit Liviu Chinezu
# 27                               Brad Booth
# 28                             Tiny Times 3
# 29                                      yes
#
#                                    response  \
# 0                                        No
# 1         Yes, both are South Korean films.
# 2                                        No
# 3                                John Beach
# 4                         Aryeh Ben-Eliezer
# 5                                       Yes
# 6                                     Noerr
# 7                          Dis-Moi Qui Tuer
# 8                           Toolbox Murders
# 9                      Week-End With Father
# 10                                      Yes
# 11                                       No
# 12              Henry Scheffé lived longer.
# 13                             Alien Origin
# 14                               Anna-Liisa
# 15                       Wanderley Oliveira
# 16                          Ramsay Anderson
# 17                   Abdul Wahab Khan Tarzi
# 18                      Overill Dwyer-Brown
# 19                             Ghar Ki Rani
# 20             Adalberto Pereira dos Santos
# 21                           Emmanuel Goffi
# 22                         Bernardo Freitas
# 23  The Last Day of School Before Christmas
# 24               Ernest William Goodpasture
# 25                                      Yes
# 26                        Tit Liviu Chinezu
# 27                               Brad Booth
# 28                             Tiny Times 3
# 29                                      Yes
#
#                                          judge_reason
# 0   The candidate response matches the ground trut...
# 1   The candidate correctly answers yes and provid...
# 2   The candidate response matches the ground trut...
# 3   The candidate response matches the ground trut...
# 4   The candidate response matches the ground trut...
# 5   The candidate response matches the ground trut...
# 6   The candidate response matches the ground trut...
# 7   The candidate response matches the ground trut...
# 8   The candidate response matches the ground trut...
# 9   The candidate response matches the ground trut...
# 10  The candidate response matches the ground trut...
# 11  The candidate response matches the ground trut...
# 12  The candidate correctly identifies Henry Schef...
# 13  The candidate response matches the ground trut...
# 14  The candidate response matches the ground trut...
# 15  The candidate response matches the ground trut...
# 16  The candidate response matches the ground trut...
# 17  The candidate response matches the ground trut...
# 18  The candidate response matches the ground trut...
# 19  The candidate response matches the ground trut...
# 20  The candidate response matches the ground trut...
# 21  The candidate response matches the ground trut...
# 22  The candidate response matches the ground trut...
# 23  The candidate response matches the ground trut...
# 24  The candidate response matches the ground trut...
# 25  The candidate correctly answers yes, matching ...
# 26  The candidate response matches the ground trut...
# 27  The candidate response matches the ground trut...
# 28  The candidate response matches the ground trut...
# 29  The candidate correctly answers yes, matching ...
